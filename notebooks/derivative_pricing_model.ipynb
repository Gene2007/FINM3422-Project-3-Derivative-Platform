# %% [markdown]
# # FINM3422 - Project 3
#
# ### Derivative Pricing Model Notebook
# ---
# **Course**: FINM3411 - Financial Modelling
#
# **Group Members**:
# 1. Gene Wu
# 2. Patrick Liu
# 3. Alex Apelt
# 4. Rohith Porthugunta
#
# **Due**: Friday 29 May 2026, 4:00pm AEST
#
# **AI Usage**: Code structure and docstrings assisted by Claude (Anthropic)
#
# ----

# %% [markdown]
# ### **Section 1: Notebook Setup and Data Loading**

# %% [markdown]
# #### 1.1 Import Required Libraries and Pricing Modules

# %%
# Import general data-anlays libraries (numpy, panadas, yfinance, scipy etc.)
# Import plotting libraries (matplotlib etc.)
# IMport file-path management tools
# Import any custom python files, modules that are only needed for this notebook from the scr/ folder

# %% [markdown]
# #### 1.2 Chart Styling and Display Settings

# %%
# Set default chart size, grid/chart style
# Set decimal display format for tables
# Set maximum columns/rows dislayed for data tables

# %% [markdown]
# #### 1.3 Load Market Inputs from Market Data and Yield Curve Notebook

# %%
# Load equity_returns.csv
# Load equity_volatility.csv
# Load correlation_matrix.csv
# Load yield_curve_processed.csv

# %% [markdown]
# ---

# %% [markdown]
# ### **Section 2: Derivative Pricing Framework Overview**

# %% [markdown]
# #### 2.1 Contract Specification Setup

# %% [markdown]
# - Explain that the project constructs hypothetical derivative contracts linked to selected Australian equities for the purpose of derivative pricing, portfolio analysis, and risk-management evaluation.
# - State that because real market derivative-contract data is not used, contract specifications are manually designed using financially reasonable assumptions based on the characteristics of each underlying equity.
# - Explain that the project analyses: European options, American options, Barrier options across different sectors of the Australian equity market.
#
# - Explain that each derivative contract requires key pricing inputs including:
#     * underlying asset price
#     * strike price
#     * maturity
#
#     * volatility
#     * risk-free interest rate
#     * barrier level (for barrier option only).
# - Explain that market inputs including historical volatility, interpolated risk-free rate, and underlying stock prices are imported from the notebook for market data and yield curve construction
#
# - Explain that the selected contract assumptions are designed to create meaningful variation in:
#     * moneyness
#     * time horizon
#     * payoff structure
#
#     * exercise flexibility
#     * path dependency
#         across the derivative portfolio.
# - State that:
#     * European options are linked to WOW.AX and CBA.AX
#     * American options are linked to BHP.AX
#
#     * Barrier options are linked to CSL.AX
#         based on the economic and market characteristics of each underlying equity.
#
# - Explain that the market inputs used throughout this notebook, including:
#     * underlying stock prices
#     * volatility estimates
#
#     * interpolated risk-free rates
#         are imported from the:

# %%
# Load the processed equity volatility dataset, processed yield curve dataset, and the processed equity-price dataset
# Exract the current stock price S(0), annualised volatility estimate, maturity-matched risk-free rates
# European option contracts were created for CBA.AX and WOW.AX --> set the strike price and maturity (explain why those values)
# American option contract was created for BHP.AX --> set the strike price and maturity (explain why)
# Barrier option contract was created for CSL.AX --> set the strike price, maturity, and barrier level (explain why)

# Calculate moneyness (ITM, ATM, OTM) using the current stock price and strike price

# Table 1 = Derivative Contract Specification Table --> columns = underlying, derivative type, option type, S(0), K, moneyness, maturity, volatility, rf rate, barrier level

# %% [markdown]
# **Interpretation: Contract Specification Setup Analysis**
#
# <u> Derivative Contract Selection Analysis - </u>
#
# - Explain why European options were selected for WOW.AX and CBA.AX by discussing how these equities generally exhibit more stable and predictable long-term price behaviour relative to highly cyclical sectors, making terminal-payoff valuation frameworks such as Black-Scholes more economically appropriate.
# - Discuss how WOW.AX, as a consumer-staples equity, exhibits relatively defensive characteristics because demand for essential consumer goods tends to remain more stable across changing economic conditions, potentially resulting in smoother price behaviour and lower downside volatility.
# - Explain how CBA.AX exhibits mature financial-sector characteristics with strong institutional ownership and relatively stable market behaviour compared with highly commodity-sensitive equities, making European-style pricing assumptions more reasonable.
#
# - Discuss why American options were selected for BHP.AX by explaining how mining-sector equities are highly cyclical and strongly exposed to:
#     * global commodity prices
#     * industrial demand
#
#     * macroeconomic uncertainty
#     * changes in investor sentiment.
# - Explain that early exercise flexibility becomes more valuable under highly volatile market conditions because investors may benefit from exercising contracts before maturity during periods of elevated commodity-price instability or sharp market movements.
#
# - Discuss why barrier options were selected for CSL.AX by explaining how barrier contracts introduce path dependency and nonlinear payoff behaviour, making them suitable for analysing advanced pricing dynamics using:
#     * Sobol Quasi Monte Carlo simulation
#
#     * Brownian Bridge adjustment.
# - Explain how CSL.AX may exhibit relatively smoother long-term growth behaviour compared with highly cyclical equities, making it suitable for analysing how path-dependent pricing behaviour changes as underlying prices approach barrier thresholds.
# - Discuss how the selected derivative-equity pairings create varying:
#     * payoff structures
#     * exercise behaviour
#
#     * sensitivity characteristics
#     * pricing complexity
#     across the portfolio.
#
#
# <u> Strike Price and Moneyness Assumption Analysis - </u>
#
# - Explain that strike prices were selected relative to each current stock price so that the contracts create meaningful ITM, ATM, and OTM pricing scenarios rather than arbitrary option inputs.
# - Discuss that using different strike levels allows the notebook to analyse how option value changes as the relationship between the stock price and strike price changes.
#
# - Explain that ATM strikes are useful because the current stock price is close to the strike price, meaning the option has little or no intrinsic value but usually has high time value and strong sensitivity to changes in the underlying stock price.
# - Discuss that ATM options are especially useful for Greeks and sensitivity analysis because Gamma and Vega effects are often strongest when the option is near the strike price.
# - Explain that OTM strikes were included because they create lower-premium contracts with no intrinsic value at initiation, allowing analysis of how option value depends on future price movement and volatility expectations.
# - Discuss that OTM options provide stronger convex payoff potential because small upfront premiums can generate large percentage gains if the underlying moves favourably, although the probability of finishing profitable is lower.
# - Explain that ITM strikes were included because they contain intrinsic value at initiation and therefore behave more like the underlying stock, with stronger Delta exposure and less pure optionality than ATM or OTM contracts.
#
# - Discuss that comparing ITM, ATM, and OTM contracts allows the analysis to separate intrinsic value, time value, Delta exposure, convexity, and payoff asymmetry across different option structures.
# - Explain that moneyness is important because it affects not only the initial option premium, but also later Greeks, sensitivity behaviour, payoff shape, and profitability outcomes.
# - Discuss that selecting strike prices across different moneyness levels improves the usefulness of the pricing notebook because it allows European, American, and barrier options to be analysed under comparable but financially distinct contract conditions.
#
# <u> Maturity Assumption Analysis - </u>
#
# - Explain that option maturities were selected to create financially realistic pricing horizons while allowing meaningful comparison between shorter-term and longer-term derivative contracts.
# - Discuss that the selected maturities were designed to balance uncertainty exposure, time value, discounting effects, and computational practicality within the broader derivative-pricing framework.
#
# - Explain that shorter maturities were selected where more concentrated short-term market exposure was desired because short-dated contracts depend more heavily on near-term stock-price movement before expiration.
# - Discuss that shorter-dated contracts generally contain lower time value because there is less remaining time for the underlying asset to experience large favourable price movements.
#
# - Explain that longer maturities were selected where greater exposure tolong-term market uncertainty, future price variability, and interest-rate effects was required.
# - Discuss that longer-dated contracts generally contain greater time value because the underlying asset has more time to experience substantial price movement prior to expiration.
# - Explain that differing maturities allow the project to analyse how derivative valuation changes across varying time horizons rather than relying on a single expiration structure.
# - Discuss that maturity selection is particularly important for discounting analysis because longer-dated derivatives are more sensitive to:
#     * interest-rate assumptions
#
#     * yield-curve interpolation
#     * present-value discounting effects.

# %% [markdown]
# #### 2.2 Pricing Methodology Selection

# %% [markdown]
# - Explain that different derivative structures require different pricing methodologies because option valuation complexity depends on:
#     * payoff structure
#     * exercise flexibility
#
#     * path dependency
#     * computational requirements.
#
# - State that this section allocates an appropriate pricing framework to each derivative type analysed throughout the project.
# - Explain that:
#     * European options are priced using the Black-Scholes model
#     * American options are priced using the Binomial Tree framework
#
#     * Barrier options are priced using Sobol Quasi Monte Carlo simulation with Brownian Bridge adjustment.
#
# - Discuss that pricing-model selection is important because no single valuation framework is appropriate for all derivative structures.
# - Explain that simpler derivatives with closed-form payoff structures may be valued analytically, while more complex derivatives require numerical or simulation-based pricing methods.
#
# - State that the selected methodologies are designed to balance:
#     * pricing accuracy
#     * computational efficiency
#
#     * modelling flexibility
#     * derivative-specific realism.
#
# - Explain that the pricing frameworks selected in this section establish the valuation environment used later for:
#     * derivative pricing
#     * Greeks analysis
#
#     * sensitivity analysis
#     * payoff analysis
#     * P&L analysis.

# %%
# Table 1 = Derivative Pricing Methodology Framework Table --> columns = underlying equity, derivative type, pricing method, key characteristics, reason for selection

# %% [markdown]
# **Interpretation: Derivative Pricing Methodology Analysis**
#
# <u> European Option Pricing Methodology Analysis - </u>
#
# - Explain that the Black-Scholes model was selected for European-option valuation because European options only permit exercise at expiration, making closed-form analytical pricing feasible.
# - Discuss that the Black-Scholes framework is computationally efficient because it produces direct analytical solutions without requiring recursive trees or large-scale simulation methods.
#
# - Explain that European options linked to WOW.AX and CBA.AX are suitable for Black-Scholes pricing because these contracts primarily depend on terminal stock-price outcomes rather than path-dependent or early-exercise behaviour.
# - Discuss that the Black-Scholes model provides analytical Greeks, allowing efficient later analysis of:
#     * Delta
#     * Gamma
#
#     * Vega
#     * Theta
#     * Rho
#         across differing moneyness and maturity conditions.
#
# - Explain that Black-Scholes establishes a useful benchmark pricing framework because it provides transparent analytical valuation and well-understood sensitivity behaviour.
# - Discuss that although Black-Scholes relies on simplifying assumptions such as:
#     * constant volatility
#     * continuous trading
#
#     * lognormal stock-price behaviour
#         the model remains widely used for European-option pricing because of its analytical tractability and computational efficiency.
#
#
# <u> American Option Pricing Methodology Analysis - </u>
#
# - Explain that the Binomial Tree framework was selected for American-option valuation because American contracts allow exercise at any point prior to expiration.
# - Discuss that early exercise flexibility cannot be captured accurately using standard Black-Scholes closed-form pricing.
#
# - Explain that the Binomial Tree model captures discrete-time stock-price evolution and recursively evaluates whether:
#     * early exercise
#
#     * continued holding
#         produces greater option value at each node.
#
# - Discuss that the Binomial Tree framework is particularly appropriate for BHP.AX because mining-sector equities often exhibit:
#     * elevated volatility
#     * cyclical behaviour
#
#     * strong sensitivity to macroeconomic conditions
#         which may increase the economic relevance of early exercise opportunities.
#
# - Explain that the tree-based structure allows flexible analysis of:
#     * changing stock-price paths
#
#     * early exercise boundaries
#     * nonlinear payoff behaviour.
#
# - Discuss that although Binomial Trees are computationally more intensive than Black-Scholes, they provide greater structural realism for contracts with early exercise rights.
#
# <u> Barrier Option Pricing Methodology Analysis - </u>
#
# - Explain that barrier options were priced using Sobol Quasi Monte Carlo simulation with Brownian Bridge adjustment because barrier-option valuation depends on the entire underlying stock-price path rather than only terminal stock price.
# - Discuss that standard analytical pricing becomes significantly more difficult for path-dependent derivatives because payoff activation or deactivation depends on whether the barrier level is crossed during the contract life.
#
# - Explain that Monte Carlo simulation is appropriate because it generates large numbers of potential stock-price paths to estimate expected option payoff behaviour under uncertainty.
# - Discuss that Sobol Quasi Monte Carlo simulation improves simulation efficiency by generating low-discrepancy sequences that produce more uniform path coverage relative to standard pseudo-random sampling.
# - Explain that Brownian Bridge adjustment improves barrier-crossing accuracy because discrete simulation intervals may otherwise fail to detect intra-step barrier crossings.
#
# - Discuss that the selected framework is particularly appropriate for CSL.AX barrier-option valuation because barrier-option pricing is highly sensitive to:
#     * path dependency
#     * barrier proximity
#
#     * volatility behaviour
#     * crossing probability.
# - Explain that although Sobol Quasi Monte Carlo simulation with Brownian Bridge adjustment is computationally intensive, it provides greater pricing realism and more accurate path-dependent valuation behaviour for complex exotic derivatives.
#
# [analyse here]

# %% [markdown]
# ---

# %% [markdown]
# ### **Section 3: European Option Pricing - Black-Scholes Valuation Framework**

# %% [markdown]
# - This section analyses the pricing and valuation behaviour of European options applied to CBA.AX and WOW.AX using the Black-Scholes option pricing framework. The section examines how option valuation responds to changes in underlying stock-price conditions, strike-price positioning, maturity assumptions, and market uncertainty within a standard vanilla-option environment.
#
# - The section applies closed-form option pricing techniques to evaluate:
#     * European-option valuation
#     * intrinsic and time value behaviour
#
#     * moneyness conditions
#     * option Greeks and sensitivity exposure
#     * payoff and profitability characteristics across varying market scenarios.
#
# - The analysis additionally compares bullish and bearish derivative exposure through the use of European call and put option structures across different Australian equities.
#
# - The following subsections establish the European-option pricing framework, valuation results, Greeks and sensitivity analysis, moneyness behaviour, and payoff and P&L characteristics within the Black-Scholes derivative framework.

# %% [markdown]
# #### 3.1 Black-Scholes Pricing Framework and Model Implementation

# %% [markdown]
# - Explain that Black-Scholes serves as the analytical benchmark framework for European option pricing
# - Discuss that Black-Scholes benchmark prices are used to evaluate Monte Carlo convergence accuracy and pricing stability
# - Explain limitations of Black-Scholes for:
#     * path-dependent derivatives
#     * barrier options
#
#     * early-exercise derivatives
#
# - Discuss main pricing assumptions (constant volatility, lognormal stock price behaviour, constant risk-free rate, no-arbitrage conditions)
# - Explain the key pricing inputs
# - Discuss how historical volatility estimates and interpolated rf rates are integrated into this framework

# %% [markdown]
# #### 3.2 European Option Valuation Results

# %%
# Calculate d1 and d2 in Black-Scholes Model
# Determine european call option price (both CBA.AX and WOW.AX)
# Determine european put option price (both CBA.AX and WOW.AX)

# Calculate IV and TV for the European call and put options of both CBA.AX and WOW.AX (use the set strike price)

# Create moneyness scenario test for European put and call options by only changein strike price (both CBA.AX and WOW.AX)
    # Define the numerical moneyness scenarios
    # Calculate option price, IV, TV for each scenario, each option type, and each equity

# Table 1 = European Option Pricing Inputs --> columbs = Underlying, Option type, S0, K, Moneyness, Volatility, rf rate, Maturity, Intrinsic Value
# Table 2 = option pricing results table --> columns = equity, option type, d1, d2, IV, TV, option price

# Graph 1 = CBA.AX European Call Moneyness Analysis --> x-axis = strike price / moneyness scenario, y-axis = option value (include IV and TV trend)
    # Purpose is to analyse how bullish European call-option valuation changes across differing moneyness conditions

# Graph 2 = WOW.AX European Put Moneyness Analysis --> x-axis = strike price / moneyness scenario, y-axis = option value (include IV and TV trend)
    # Purpose is to analyse how bearish European put-option valuation changes across differing moneyness conditions
    # Place Graph 1 and Graph 2 next to each other as one figure for comparative interpretation
    
# Required Test: Put-Call Parity Check

# %% [markdown]
# **Interpretation: Option Pricing Results Analysis**
#
# <u>Overall Pricing Behaviour - </u>
# - Analyse whether European option premiums appear reasonable relative to:
#     * stock price
#     * strike price
#
#     * maturity
#     * volatility assumptions.
#
# - Discuss how option premiums reflect:
#     * expected future payoff potential
#
#     * remaining time until expiry
#     * uncertainty surrounding future stock-price movement.
#
# - Analyse whether option valuation behaviour appears linear or nonlinear across differing strike-price scenarios.
#
#
# <u>Option Moneyness Analysis - </u>
# - State that varying strike prices created ITM/ATM/OTM moneyness scenarios for CBA.AX and WOW.AX
#
# - Analyse how ITM call options exhibit greater intrinsic value and higher option premiums because the stock price exceeds the strike price.
#
# - Explain how ATM call options typically contain substantial time value because small stock-price movements strongly affect exercise profitability.
# - Discuss how OTM call options contain little or no intrinsic value but may still retain time value due to future upside potential.
#
# - Analyse how the line graph demonstrates the relationship between:
#     * strike-price positioning
#
#     * intrinsic value
#     * time value
#         within bullish European-option exposure.
#
# * Analyse how ITM put options exhibit greater intrinsic value because the strike price exceeds the stock price.
# * Explain how ATM put options retain significant time value because future downside uncertainty influences expected payoff potential.
# * Discuss how OTM put options may still retain option premium despite limited intrinsic value due to possible future downside movement.
#
# * Analyse how the line graph demonstrates the relationship between:
#     * strike-price positioning
#
#     * intrinsic value
#     * time value
#         within bearish European-option exposure.
#
# [analyse here]

# %% [markdown]
# #### 3.3 Option Greeks and Sensitivity Analysis

# %% [markdown]
# ##### 3.3.1 Option Greeks Analysis

# %%
# Calculate delta, gamma, vega, theta for each European option
# Table 1 = European Greeks Summary Table --> columns = option, underlying, type, strike, moneyness, delta, gamma, vega, theta

# Graph 1 = Delta vs Stock Price (call and put)
# Graph 2 = Gamma vs Stock Price (call and put)
    # Put Graph 1 and Graph 2 next to each other to analyse directional exposure and convexity

# Graph 3 = Vega vs Volatility (call and put)
# Graph 4 = Theta vs Time to Maturity (call and put)
    # Put Graph 3 and Graph 4 next to each other to analyse volatility exposure and time decay

# %% [markdown]
# **Interpretation: Option Greeks Analysis**
#
# (note: some of this may belong in the introduction part before the option greeks analysis code)
#
# <u> Delta and Directional Exposure Analysis - </u>
# - Analyse the relationship between underlying stock-price movement and option valuation by discussing how Delta measures the sensitivity of option value to small changes in the underlying stock price.
# - Explain that call-option Delta is positive because call values generally increase as stock prices rise, while put-option Delta is negative because put values generally increase as stock prices fall.
# - Explain that only the Delta value is affected by whether option is put or call --> other greeks are not impacted (** move this to the introduction part)
#
# - Discuss how Delta magnitude changes across moneyness regions and explain that:
#     * ITM call options generally exhibit Delta values closer to +1
#
#     * ITM put options generally exhibit Delta values closer to −1
#         because these contracts behave more similarly to the underlying asset itself.
# - Analyse how ATM options often exhibit the greatest change in Delta behaviour because small stock-price movements near the strike price significantly alter the probability of profitable expiration.
# - Explain that OTM options generally exhibit lower absolute Delta values because their probability of finishing profitably remains relatively low under current market conditions.
#
# - Discuss how Delta reflects directional market exposure and explain that larger absolute Delta values imply greater sensitivity to stock-price movement and stronger directional risk exposure.
# - Analyse whether Delta behaviour appears approximately linear or nonlinear across differing stock-price regions and explain how option valuation becomes increasingly nonlinear near ATM conditions.
#
# <u> Gamma and Convexity Analysis - </u>
# - Explain that Gamma measures the rate of change of Delta and therefore captures how rapidly directional exposure changes as the underlying stock price moves.
# - Discuss why Gamma generally peaks near ATM regions because small stock-price movements around the strike price produce the largest changes in exercise probability and option sensitivity.
#
# - Analyse whether Gamma declines for deep ITM and deep OTM contracts and explain how Delta becomes more stable once exercise outcome becomes increasingly certain.
# - Discuss how high Gamma implies stronger convexity behaviour and greater sensitivity to rapid underlying stock-price movement.
# - Explain that Gamma becomes particularly important for dynamic hedging because rapidly changing Delta exposure may require more frequent hedge adjustment.
#
# <u> Vega and Volatility Exposure Analysis - </u>
# - Analyse the relationship between volatility and option sensitivity by discussing how Vega measures the responsiveness of option value to changes in expected future volatility.
# - Explain that option value generally increases as volatility rises because greater uncertainty increases the probability of large favourable stock-price movements prior to expiration.
#
# - Discuss why ATM options often exhibit stronger Vega exposure because volatility changes most strongly affect contracts whose final exercise outcome remains uncertain.
# - Analyse whether longer-dated options exhibit larger Vega values and explain how additional time to maturity increases exposure to future volatility uncertainty.
# - Discuss how Vega analysis provides insight into volatility-risk exposure and explain why volatility assumptions are critically important within derivative valuation frameworks.
#
# <u> Theta and Time Decay Analysis - </u>
# - Explain that Theta measures the rate at which option value declines as expiration approaches due to the gradual erosion of time value.
# - Discuss how option time value decreases as maturity shortens because there is less remaining time for the underlying stock price to experience favourable movement before expiration.
#
# - Analyse whether short-dated options exhibit more rapid Theta decay and explain how time decay accelerates as expiration approaches.
# - Discuss why ATM contracts often exhibit stronger Theta exposure because they contain substantial time value and uncertain final exercise outcomes.
# - Explain that Theta analysis is important because time decay represents a direct source of option-value erosion even if the underlying stock price remains unchanged.
#
# [analyse here]

# %% [markdown]
# ##### 3.3.2 Option Sensitvity Analysis

# %%
# Calculate call and put option prices across changing stock prices
# Calculate call and put option prices across changing volatility levels
# Calculate call and put option prices across changing time to maturity
# Calculate call and put option prices across changing interest rates

# Graph 5 = Call and Put Option Value vs Stock Price --> x-axis = stock price, y-axis = option value
    # plot both call and put option values against stock price
    # Purpose = analyse how European call and put option values respond differently to underlying stock-price movement

# Graph 6 = Call and Put Option Value vs Volatility --> x-axis = volatility, y-axis = option value
    # plot both call and put option values against volatility
    # Purpose = analyse how European call and put option values respond to changing volatility assumptions

# Graph 7 = Call and Put Option Value Surface across Strike and Volatility --> x-axis = strike price or moneyness, y-axis = volatility, z-axis/colour = option value
    # generate separate surfaces for call and put options
    # Purpose = analyse the interaction between strike selection, volatility assumptions, moneyness, and European option valuation

# Graph 8 = Call and Put Option Value vs Time to Maturity --> x-axis = time to maturity, y-axis = option value
    # plot both call and put option values against maturity
    # Purpose = analyse how European call and put option values change as maturity changes

# %% [markdown]
# **Interpretation: Option Sensitivity Analysis**
#
# <u> Sensitivity to Underlying Stock Price - </u>
# - Analyse the relationship between underlying stock-price movement and European-option valuation by discussing how option prices respond nonlinearly to changing market conditions.
# - Discuss how call-option values generally increase as stock prices rise while put-option values generally decrease as stock prices rise because exercise profitability changes with underlying-price movement.
# - Explain that put-option values generally decrease as stock prices rise because rising stock prices reduce the probability that put options finish profitably at expiration.
# - Analyse whether option-price behaviour appears linear or nonlinear across differing stock-price regions and explain how convex payoff structures create asymmetric pricing behaviour.
#
# - Discuss how option-value sensitivity becomes stronger near ATM regions because small stock-price movements significantly alter exercise probability and intrinsic-value expectations.
# - Analyse how stock-price sensitivity differs across ITM, ATM, and OTM contracts and explain how moneyness influences pricing responsiveness and payoff asymmetry.
# - Explain how sensitivity to stock-price movement reflects overall directional market exposure and contributes significantly to derivative risk behaviour.
#
# <u> Sensitivity to Volatility - </u>
# - Analyse the relationship between volatility assumptions and option valuation by discussing how higher expected volatility generally increases both call-option and put-option value.
# - Explain that greater volatility increases the probability of large favourable stock-price movement prior to expiration, thereby increasing option time value and uncertainty exposure for both calls and puts.
# - Discuss whether option values respond smoothly or aggressively to changing volatility assumptions and explain how volatility sensitivity may become stronger near ATM conditions.
#
# - Analyse how volatility sensitivity differs across ITM/ATM/OTM and explain why ATM contracts often exhibit the strongest responsiveness to volatility shocks.
# - Discuss how volatility exposure is particularly important for derivative valuation because option pricing depends heavily on expectations regarding future stock-price uncertainty.
# - Analyse the Option Value Surface across Strike and Volatility and discuss how the interaction between:
#     * strike selection
#
#     * moneyness
#     * volatility assumptions
#         jointly influences option valuation behaviour.
# - Explain how the surface plot demonstrates that differing combinations of moneyness and volatility may produce substantially different pricing outcomes and risk characteristics.
#
# <u> Senstivity to Time Maturity - </u>
# - Analyse the relationship between time to maturity and European-option valuation by discussing how longer maturities generally increase both call-option and put-option value due to greater remaining uncertainty and larger time value.
# - Explain that longer-dated contracts provide more opportunity for favourable stock-price movement prior to expiration, increasing expected payoff potential for both calls and puts.
# - Discuss how shorter maturities reduce time value because there is less remaining opportunity for substantial stock-price movement before expiration.
#
# - Analyse how time-decay behaviour accelerates as options approach expiration and explain how this effect becomes particularly important for short-dated contracts.
# - Discuss how maturity sensitivity affects option valuation differently across ITM, ATM, and OTM regions because moneyness influences the relative importance of intrinsic value versus time value.
# - Explain how maturity sensitivity analysis provides insight into:
#     * time-value behaviour
#
#     * expiration risk
#     * discounting effects
#         within the broader derivative-pricing framework.
#
# [analyse here]

# %% [markdown]
# #### 3.4 Option Payoff and P&L Behaviour Analysis

# %%
# Calculate long call payoff and P&L across terminal stock prices
# Calculate short call payoff and P&L across terminal stock prices

# Calculate long put payoff and P&L across terminal stock prices
# Calculate short put payoff and P&L across terminal stock prices

# Graph 1 = Long vs Short Call Option Payoff and P&L Diagram --> x-axis = terminal stock price, y-axis = payoff / profit-loss
    # plot: long call payoff/P&L in Graph 1 and short call payoff/P&L in Graph 2 but same figure
    # Purpose = analyse directional exposure, convex payoff behaviour, premium effects, break-even behaviour, and asymmetric risk-return characteristics of long and short call-option positions

# Graph 3 = Long vs Short Put Payoff and P&L Diagram --> x-axis = terminal stock price, y-axis = payoff / profit-loss
    # Purpose = analyse downside protection behaviour, bearish market exposure, premium effects, break-even behaviour, and asymmetric risk-return characteristics of long and short put-option positions

# Optional:
    # Add vertical reference lines for:
    # strike price
    # break-even prices
    #zero P&L line
# Purpose = improve interpretation of payoff transitions, profitability thresholds, and option exercise regions

# %% [markdown]
# **Interpretation: Option Payoff and P&L Diagram Analysis**
#
# <u> Call Option Payoff and P&L Analysis - </u>
# - Analyse how long call-option payoff increases once terminal stock price rises above the strike price because the option gains intrinsic value when market prices move favourably above the exercise level.
# - Discuss how long call-option positions exhibit theoretically unlimited upside profit potential as stock prices continue increasing above the strike price.
#
# - Explain that maximum downside loss for long call positions is limited to the initial premium paid if the option expires worthless.
# - Analyse how short call-option positions exhibit the opposite payoff structure because the option writer receives the premium initially but faces increasing losses as stock prices rise substantially above the strike price.
# - Discuss how short call positions exhibit limited maximum profit equal to the premium received but potentially unlimited downside risk due to unlimited stock-price upside exposure.
# - Explain how payoff diagrams differ from P&L diagrams because option premiums shift profitability profiles by the initial option cost or premium received.
#
# - Discuss the break-even stock price and explain that profitability only occurs once terminal stock price moves sufficiently beyond the strike price to offset the premium effect.
# - Analyse how both long and short call-option payoff structures exhibit nonlinear and convex pricing behaviour because profitability changes disproportionately as the option moves further ITM.
# - Explain how long and short call positions create opposite directional market exposure:
#     * long calls benefit from rising markets
#
#     * short calls benefit from stable or declining markets.
# - Discuss how option contracts provide leveraged exposure because relatively small premium outlays or premium receipts may generate disproportionately large profit or loss outcomes under changing market conditions.
#
# <u> Put Option Payoff and P&L Analysis - </u>
# - Analyse how long put-option payoff increases as terminal stock prices decline below the strike price because falling stock prices increase put-option intrinsic value.
# - Discuss how long put positions provide downside protection during declining market conditions and therefore may be useful for hedging adverse market exposure.
#
# - Explain that maximum downside loss for long put positions is limited to the premium initially paid if the option expires worthless.
# - Analyse how short put-option positions exhibit the opposite payoff structure because the option writer benefits if market prices remain stable or rise above the strike price but faces increasing losses as stock prices decline substantially.
# - Discuss how short put positions exhibit limited maximum profit equal to the premium received while downside losses may become substantial if stock prices fall significantly below the strike price.
# - Explain how payoff diagrams differ from P&L diagrams because option premiums alter the final profitability profile and shift break-even levels away from the strike price.
#
# - Discuss the break-even stock price and explain that positive profitability for long put positions only occurs once terminal stock price declines sufficiently below the strike price to offset the premium paid.
# - Analyse how long and short put-option payoff structures exhibit asymmetric downside exposure because profitability changes nonlinearly as market declines become larger.
# - Explain how long and short put positions create opposite market exposure:
#     * long puts benefit from declining markets
#
#     * short puts benefit from stable or rising markets.
#
# [analyse here]

# %% [markdown]
# ---

# %% [markdown]
# ### **Section 4: American Option Pricing - Binomial Tree Framework**

# %% [markdown]
# - This section analyses the pricing and valuation behaviour of American options applied to BHP.AX using the Cox-Ross-Rubinstein (CRR) binomial-tree framework. Unlike standard European options, American options provide the holder with the flexibility to exercise the contract at any point prior to expiration, introducing additional strategic and valuation complexity within the derivative structure.
# - The section therefore examines how early exercise flexibility influences option valuation, exercise incentives, and contract behaviour under varying market conditions within the BHP.AX derivative environment.
#
# - To evaluate these dynamics, the section applies a multi-period binomial pricing framework to analyse:
#     * American-option valuation
#     * intrinsic and continuation value behaviour
#
#     * early exercise incentives
#     * option Greeks and sensitivity exposure
#     * conditional payoff behaviour across different stock-price scenarios.
#
# - The following subsections establish the American-option pricing framework, valuation outputs, Greeks and sensitivity analysis, and early exercise behaviour within the CRR binomial-tree framework.

# %% [markdown]
# #### 4.1 Binomial Tree Pricing Framwork

# %% [markdown]
# - Explain that American options differ from European options because they may be exercised at any time prior to expiration rather than only at maturity
# - Discuss why closed-form Black-Scholes valuation is generally unsuitable for American options because early exercise introduces path-dependent exercise decisions across time
#
# - Explain that the Cox-Ross-Rubinstein (CRR) binomial-tree framework models stock-price evolution through discrete up and down movements across multiple time intervals
# - Discuss how the recombining tree structure allows efficient modelling of possible future stock-price paths while preserving dynamic pricing behaviour
# - Explain that the American-option pricing process uses backward induction by comparing:
#     * continuation value
#
#     * immediate exercise value
#         at every node to determine optimal exercise behaviour.
# - State that this subsection constructs the pricing framework required to value American options while incorporating early-exercise flexibility and time-varying stock-price evolution.
#
# This section is for the theory component of the binomial tree pricing framework (NOTE: Use theory but dont make it too detailed)
#
# [write here]

# %%
# Define American option contract parameters --> Input: underlying stock price, strike price, maturity, volatility, risk-free interest rate, number of tree steps

# Calculate timestep size --> dt = T / N
# Calculate CRR up factor --> u = exp(sigma * sqrt(dt))
# Calculate CRR down factor --> d = 1 / u

# Calculate risk-neutral probability --> p = (exp(r * dt) - d) / (u - d)
# Calculate discount factor --> exp(-r * dt)

# (Check with FINM3405 lecture notes to ensure that formula is correct)

# Construct recombining stock-price lattice
# Construct terminal option payoffs
# Apply backward induction

# Compare: continuation value and immediate exercise value at each node
# Determine optimal early-exercise regions

# Table 1 = American Option Contract Specification Table --> columns = underlying asset, option type, position, strike price, maturity, volatility, rf rate, tree steps
# Table 2 = Binomial Tree Parameter Table --> columns = timestep size, up factor, down factor, risk-neutral probability, discount factor
# Table 3 = Node-Level Exercise Decision Table --> columns = node, stock price, continuation value, exercise value, optimal decision

# Graph 1 = Binomial Stock Price Tree --> x-axis = timestep, y-axis = stock price
    # Include a node-level early exercise decision visualisation --> bascially just at which nodes the contract is exercise early and at which nodes they are held
    # Purpose is to visualise discrete stock-price evolution axross the recombining lattice framework and shows where early exercise becomes optimal inside the tree

# %% [markdown]
# **Interpretation: Binomial Tree Pricing Framework Analysis**
#
# - Analyse how the recombining stock-price lattice models possible future stock-price evolution through discrete upward and downward market movements across multiple timesteps.
# - Discuss how the binomial-tree framework approximates continuous stock-price behaviour by dividing the option life into smaller discrete time intervals.
#
# - Explain how the CRR:
#     * up factor
#
#     * down factor
#         determine the magnitude of possible stock-price movement at each node within the lattice structure.
#
# - Analyse how higher volatility increases stock-price dispersion throughout the tree and explain how greater uncertainty produces wider separation between upward and downward price paths.
# - Discuss how increasing the number of tree steps improves pricing precision because finer timestep resolution better approximates continuous-time market behaviour.
# - Explain how the recombining tree structure improves computational efficiency because identical stock-price states merge together across time rather than generating entirely separate pricing paths.
# - Discuss how the stock-price lattice visually demonstrates the range of possible future market outcomes rather than relying on a single expected stock-price forecast.
#
# [analyse here]

# %% [markdown]
# **Interpretation: Risk-Neutral Valuation Framework Analysis**
#
# - Explain how risk-neutral probabilities are applied within the no-arbitrage pricing framework to generate theoretically consistent option valuation.
# - Discuss how the risk-neutral probability does not represent the true probability of stock-price movement but instead produces pricing consistency under risk-neutral valuation assumptions.
#
# - Analyse how expected future option payoffs are discounted back to present value using the risk-free interest rate within the backward-induction framework.
# - Explain how the discount factor incorporates the time value of money by converting future expected option values into present-value terms.
#
# - Discuss how the combination of:
#     * stock-price evolution
#
#     * risk-neutral probabilities
#     * present-value discounting
#         creates a complete discrete-time derivative valuation framework.
#
# [analyse here]

# %% [markdown]
# **Interpretation: Backward Induction and Early Exercise Framework Analysis**
#
# - Explain how backward induction prices American options by recursively working backward from terminal option payoffs toward the present valuation date.
#
# - Discuss how the valuation framework compares:
#     * continuation value
#
#     * immediate exercise value
#         at every node within the lattice structure to determine whether exercising the option early becomes optimal.
# - Analyse how the node-level early-exercise visualisation identifies regions where immediate exercise value exceeds continuation value and therefore early exercise becomes economically rational.
# - Discuss how regions where continuation value exceeds immediate exercise value indicate that holding the option preserves additional time value and future payoff opportunity.
#
# - Explain how the framework dynamically incorporates early-exercise flexibility throughout the option life rather than restricting exercise decisions solely to maturity.
# - Discuss how the binomial-tree framework is particularly suitable for American-option pricing because the node-by-node structure naturally accommodates dynamic exercise decisions across time.
# - Explain how the framework establishes the pricing environment required for later:
#
# [analyse here]

# %% [markdown]
# #### 4.2 American Option Valuation Results

# %%
# Calculate AMerican call-option prices using the CRR binomial-tree framework (actual strike price)
# Calculate American put-option prices using the CRR binomial-tree framework (actual strike price)

# Calculate IV, TV for the American put and call option contract (underlying asset is BHP)

# Create moneyness scenario test for American put and call options by only changein strike price (use BHP S0 stock price)
    # Define the strike price scenarios using the (FINM3405 --> it will be numberical not ITM/ATM/OTM)
    # Calculate option price, IV, TV for each scenario and for each option type

# Table 1 = American Option Pricing Results Table --> columns = underlying asset, option type, position, strike price, maturity, American Option Value, IV, TV

# Graph 1 = American Call Option Value across Moneyness Scenarios --> x-axis = moneyness (numerical), y-axis = value, trend = IV, TV, f
    # Purpose is to anlayse how total value for american call option changes and is decomposed into IV and remaining TV across differing moneyness conditions
    
# Graph 2 = American Put Option Value across Moneyness Scenarios --> x-axis = moneyness (numerical), y-axis = value, trend = IV, TV, f
    # Purpose is to anlayse how total value for american put option changes and is decomposed into IV and remaining TV across differing moneyness conditions

# %% [markdown]
# **Interpretation: American Option Value Analysis**
#
# - Analyse how American call-option and put-option values change across differing strike-price scenarios and explain how varying payoff structures influence total option valuation behaviour.
# - Discuss how American call-option values generally increase as strike prices move further below the current underlying stock price because favourable exercise potential increases.
#
# - Analyse how American put-option values generally increase as strike prices move further above the current underlying stock price because downside exercise profitability becomes more valuable.
# - Discuss how American-option valuation incorporates early-exercise flexibility because option holders may exercise prior to expiration if immediate exercise becomes economically beneficial.
# - Analyse whether deep ITM scenarios exhibit stronger immediate exercise incentives because immediate exercise value contributes a larger proportion of total option valuation.
#
# [analyse here]

# %% [markdown]
# **Interpretation: Moneyness, Intrinsic Value, and Time Value Analysis**
#
# - Analyse how moneyness classification is determined by comparing the current BHP stock price against the strike price and discuss how:
#     * ITM contracts contain greater intrinsic value
#
#     * ATM contracts retain greater sensitivity to future stock-price movement
#     * OTM contracts rely more heavily on remaining time value and future uncertainty.
#
# - Analyse the relationship between intrinsic value and total option value and explain how American-option premiums contain both:
#     * immediate exercise value
#
#     * remaining time value.
#
# - Discuss how intrinsic value changes across moneyness scenarios and explain why:
#     * ITM contracts exhibit larger intrinsic-value contribution
#
#     * ATM contracts exhibit balanced intrinsic and time-value exposure
#     * OTM contracts contain limited or zero intrinsic value.
#
# - Analyse how time value reflects remaining uncertainty and future exercise opportunity prior to expiration.
# - Discuss how OTM contracts may still retain positive option value despite having no immediate exercise value because future stock-price movement may still create profitable exercise opportunity before maturity.
#
# - Analyse whether remaining time value declines relative to intrinsic value as contracts move deeper ITM because immediate exercise value increasingly dominates total option valuation.
# - Explain how varying strike-price assumptions while holding:
#     * underlying stock price
#     * maturity
#
#     * volatility
#     * risk-free rate
#         constant isolates the impact of moneyness on American-option valuation behaviour.
#
# - Analyse whether option-value behaviour across moneyness scenarios appears linear or nonlinear and discuss how convex payoff structures contribute to asymmetric derivative valuation behaviour.
# - Explain how the decomposition between intrinsic value and time value provides insight into:
#     * exercise incentives
#
#     * remaining uncertainty
#     * future payoff opportunity
#         within American-option valuation behaviour.
#
# [analyse here]

# %% [markdown]
# #### 4.3 American Option Greeks and Sensitivity Analysis

# %% [markdown]
# ##### 4.3.1 Option Greeks Analysis

# %%
# Calculate Delta, Gamma, Vega, and Theta for each american option type

# Graph 1 =

# %% [markdown]
# **Interpretation: Option Greeks Analysis**
#
# [analyse here]

# %% [markdown]
# ##### 4.3.2 Option Sensitivity Analysis

# %%
# Code here

# %% [markdown]
# **Interpretation: Option Sensitivity Analysis**
#
# [analyse here]

# %% [markdown]
# #### 4.4 Option Payoff and P&L Analysis

# %%
# Calculate long/short call payoff and P&L across terminal stock prices

# Calculate long/short put payoff and P&L across terminal stock prices

# Table 1 = American Option Exercise and P&L Summary Table --> collumns = option type, position, strike price, premium, breakeven price, maximum profit, maximum loss, 

# Graph 1 = Long vs Short Call Option Payoff and P&L Diagram --> x-axis = terminal stock price, y-axis = payoff / profit-loss
# Graph 2 = Long vs Short Put Payoff and P&L Diagram --> x-axis = terminal stock price, y-axis = payoff / profit-loss

# Optional:
    # Add vertical reference lines for:
    # strike price
    # break-even prices
    #zero P&L line
# Purpose = improve interpretation of payoff transitions, profitability thresholds, and option exercise regions

# %% [markdown]
# **Interpretation: Option Payoff and P&L Diagram Analysis**
#
# (NOTE: Payoff and P&L may not be analyed for american options as it is repetitive)

# %% [markdown]
# #### 4.5 Early Exercise Analysis

# %% [markdown]
# - This subsection analyses the early exercise behaviour of American options within the Cox-Ross-Rubinstein (CRR) binomial-tree framework. Unlike European options, American-option holders may exercise the contract at any point prior to expiration, creating an additional exercise-timing decision within the valuation process.
#
# - The analysis compares continuation value and immediate exercise value across differing stock-price and maturity conditions to identify regions where continued holding or early exercise becomes economically optimal.
#
# [introduce here]

# %%
# Calculate continuation value --> it is discounted expected value of continuing to hold the American option at each node in the CRR binomial tree
    # Purpose = measure the remaining future opportunity??
# Calculate immediate exercise value --> the put and call intrinsic value at each node
    # Purpose = measure the value obtained from exercising the option immediately

# Perform optimal exercise decision --> compare continuation value vs immediate exercise value
    # Hold option if continuation value is larger
    # Exercise if immediate exercise value is larger
    # Purpose = identify the optimal exercise behaviour

# Table 1 = Early Exercise Decision Summary Table --> columns = timestep, stock price, continuation value, intrinsic value, optimal decision
# Table 2 = Early Exercise Incentive Summary Table --> columns = scenario (deep ITM, deep OTM etc.), likely exercise behaviour, reason

# Graph 1 = Early Exercise Boundary Visualisation for American call and put option--> x-axis = stock price, y-axis = time to maturity, regions = shaded HOLD/EXERCISE region

# %% [markdown]
# **Interpretation: Early Exercise Analysis**
#
# <u> Continuation Value vs Immediate Exercise Value </u>
# - Analyse how American-option holders compare continuation value and immediate exercise value at each node within the CRR binomial-tree framework when determining the optimal exercise decision.
#
# - Explain that continuation value represents the discounted expected value of continuing to hold the option because future stock-price movement may further improve profitability before expiration, while immediate exercise value represents the intrinsic value obtained from exercising the contract immediately.
# - Discuss how the optimal exercise decision depends on whether continuation value or immediate intrinsic value provides the greater economic benefit to the option holder.
#
#
# <u> Early Exercise Boundary and Exercise Region Behaviour </u>
# - Analyse how the Early Exercise Boundary Visualisation identifies:
#     * HOLD regions
#
#     * EXERCISE regions
#         across differing stock-price levels and time-to-maturity conditions.
# - Explain how exercise regions generally expand as expiration approaches because remaining time value declines over time and future continuation opportunity becomes more limited.
#
# - Discuss how continuation regions remain dominant when future stock-price uncertainty still provides meaningful additional option value beyond immediate exercise profitability.
# - Analyse how the visualisation demonstrates the trade-off between preserving future option opportunity and capturing immediate intrinsic value.
#
#
# <u> American Put Early Exercise Behaviour</u>
# - Analyse why deep ITM American put options are more likely to exhibit early exercise incentives because substantial intrinsic value may outweigh remaining continuation value, particularly near expiration.
# - Discuss how declining stock prices increase put-option intrinsic value and therefore increase the attractiveness of immediate exercise within bearish market conditions.
#
# - Explain how near-expiration American put contracts may exhibit stronger exercise incentives because remaining future upside from continued holding becomes limited.
# - Analyse how early exercise flexibility increases the economic attractiveness of deep ITM American put positions near expiration.
#
#
# <u> American Call Early Exercise Behaviour </u>
# - Discuss why early exercise of American call options is often economically suboptimal for non-dividend-paying stocks because continued holding preserves remaining upside participation and time value.
#
# - Analyse how American call options therefore tend to remain within HOLD regions for a larger proportion of the option life.
#
#
#
# [analyse here]

# %% [markdown]
# ---

# %% [markdown]
# ### **Section 5: Barrier Option Pricing - Sobol Quasi-Monte Carlo Framework**

# %% [markdown]
# - This section analyses the pricing and valuation behaviour of a barrier option applied to CSL.AX using a Sobol Quasi Monte Carlo simulation framework. The section extends the earlier European and American option analysis by introducing an exotic derivative structure with conditional payoff behaviour linked to a predefined barrier level.
# - The barrier-option framework therefore examines how stock-price evolution throughout the contract life influences option valuation, barrier activation behaviour, and conditional payoff outcomes within the CSL.AX derivative environment.
#
# - To model these dynamics, the section applies simulation-based pricing techniques to analyse:
#     * barrier-option valuation
#     * stock-price path behaviour
#
#     * barrier activation/deactivation conditions
#     * path-dependent sensitivity behaviour
#     * conditional payoff exposure.
#
# - The following subsections establish the barrier-option pricing framework, simulation methodology, valuation results, Greeks and sensitivity analysis, and barrier activation behaviour within the Sobol Quasi Monte Carlo derivative framework.

# %% [markdown]
# #### 5.1 Barrier Option Pricing Framework

# %%
# Define the barrier option contract assumptions: underlying asset (CSL.AX), option type, strike price, barrier level, maturity, volatility, risk-free rate
# Define the barrier-option structure --> knock-in or knock-out / up barrier or down barrier

# Establish the barrier activation/deactivation conditionis
# Store all pricing and simulation assumptions for reproducibility and consistency throughout the Monte Carlo pricing

# Table 1 = Barrier Option Contract Specification Table --> columns = underlying asset, option type, strike price, barrier level, maturity, volatility, risk-free rate

# %% [markdown]
# **Interpretation: Barrier Option Structure and Path Dependency**
#
# - Analyse how barrier options differ fundamentally from vanilla European and American options because payoff eligibility depends on whether the underlying stock price crosses a predetermined barrier level during the option life rather than solely on terminal stock-price outcomes at expiration.
# - Discuss how this conditional payoff structure creates path dependency because the sequence of stock-price movements throughout the contract life becomes economically significant to the final option payoff.
#
# - Explain how knock-in structures require barrier activation before the option becomes economically valid, while knock-out structures deactivate the option once the barrier level is breached.
# - Analyse how barrier options therefore exhibit discontinuous valuation behaviour because relatively small changes in stock-price paths near the barrier level may substantially alter payoff eligibility and overall option value.
# - Discuss how barrier-option valuation is heavily influenced by:
#     * barrier proximity
#     * volatility
#
#     * stock-price path behaviour
#     * barrier-crossing probability
#
#         rather than solely intrinsic value at maturity.
# - Explain how identical terminal stock prices may generate different payoff outcomes depending on whether the barrier level was breached during the option life

# %% [markdown]
# **Interpretation: Barrier Pricing Framework Justification**
#
# - Analyse why simulation-based pricing methods are more appropriate for barrier-option valuation because the derivative payoff depends on stock-price evolution throughout the contract life rather than solely on terminal stock-price outcomes.
# - Discuss how standard Black-Scholes pricing frameworks become less suitable because vanilla closed-form pricing models do not effectively capture path-dependent barrier-crossing behaviour during the simulation horizon.
#
# - Explain how barrier-option pricing requires continuous monitoring of stock-price paths to determine whether payoff activation or deactivation conditions are satisfied before expiration.
# - Discuss how simulation-based pricing frameworks allow more realistic modelling of:
#     * barrier-crossing probability
#
#     * conditional payoff outcomes
#     * path-dependent stock-price evolution
#
#         within the CSL.AX barrier-option framework.

# %% [markdown]
# #### 5.2 Sobol Quasi-Monte Carlo Simulation Framework

# %%
# Generate Sobol low-discrepancy sequences
    # Purpose = create more evenly distributed simulation inputs relative to standard pseudo-random Monte Carlo simulation

# Convert Sobol uniform draws into standard normal random variables
    # Purpose = generate stochastic shocks for stock-price path simulation

# Simulate CSL.AX stock-price paths using Geometric Brownian Motion (GBM) --> Inputs: current stock price, volatility, risk-free rate, maturity, timestep count, simulation count

# Simulate stock-price evolution across all timesteps and simulations
    # Purpose = model possible stock-price paths throughout the option life

# Monitor each simulated stock-price path for barrier breaches
    # Purpose = determine whether the barrier level is crossed during the contract horizon

# Apply Brownian Bridge barrier adjustment
    # Purpose = estimate barrier-crossing probability between discrete simulation timesteps and reduce missed barrier-crossing events

# Store simulated stock-price paths and barrier status
    # Purpose = retain simulation outputs for later valuation, sensitivity, and payoff analysis

# Table 1 = Sobol Quasi-Monte Carlo Simulation Parameter Table --> columns = simulation count,timestep count, timestep size, Sobol dimensions, volatility, maturity, risk-free rate, Brownian Bridge adjustment used

# Graph 1 = Simulated CSL.AX Stock-Price Paths with Barrier Level --> x-axis = timestep, y-axis = simulated stock price
    # include: multiple simulated stock-price paths, horizontal barrier line
    # Purpose = visualise stock-price path evolution, barrier proximity, and barrier-crossing behaviour

# Graph 2 = Moneyness vs Simulation Efficiency --> x-axis = moneyness, y-axis = variance (error)
    # Purpose - show that monte carlo is less efficient for OTM options

# %% [markdown]
# **Interpretation: Sobol Quasi-Monte Carlo Path Generation**
#
# - Analyse how Sobol low-discrepancy sequences improve simulation efficiency by generating more evenly distributed simulation inputs relative to standard pseudo-random Monte Carlo simulation.
# - Discuss how standard Monte Carlo simulation may produce clustering behaviour across simulated paths, potentially slowing convergence and increasing pricing variance within barrier-option valuation.
# - Discuss how Sobol low-discrepancy sequences improve the quality of the simulation inputs by spreading generated points more evenly across the probability space than standard pseudo-random Monte Carlo draws.
#
# - Explain that this matters for the barrier option because uneven random-path clustering can distort estimated barrier-crossing behaviour, especially when option value is sensitive to whether paths move close to the barrier level.
# - Discuss how the Sobol framework therefore improves numerical reliability within path-dependent derivative pricing environments where barrier-crossing behaviour significantly influences final option valuation.
# - Analyse whether the simulation design appears sufficiently reliable by linking the number of paths and timestep frequency in the parameter table to the smoothness and coverage of the simulated stock-price paths shown in Graph 1.

# %% [markdown]
# **Interpretation: Geometric Brownian Motion Stock-Price Simulation**
#
# - Analyse how the Geometric Brownian Motion (GBM) framework models possible CSL.AX stock-price evolution throughout the contract life using:
#     * volatility
#     * maturity
#
#     * risk-free rate
#     * stochastic price shocks.
#
# - Explain that the CSL.AX stock-price paths are generated using the GBM process:
#
# $S_{t+\Delta t}=S_t\exp\left[\left(r-\frac{1}{2}\sigma^2\right)\Delta t+\sigma\sqrt{\Delta t}Z\right]$
#
# where $S_t$ is the stock price, $r$ is the risk-free rate, $\sigma$ is volatility, $\Delta t$ is the timestep size, and $Z$ is the standard normal shock generated from the Sobol sequence.
#
# - Discuss how higher volatility increases dispersion across simulated stock-price paths and therefore increases the probability of barrier-crossing events during the simulation horizon.
# - Explain how stock-price path simulation is necessary because identical terminal stock prices may generate different barrier-option outcomes depending on whether the barrier level was breached earlier in the contract life.
#
# - Discuss how Graph 1 demonstrates the need for path simulation because the barrier option depends on whether the CSL.AX path crosses the barrier at any point, not only on where the path finishes at maturity.
# - Analyse whether the simulated paths appear economically reasonable by checking whether they evolve continuously through time and whether some paths approach or cross the barrier level under the selected volatility and maturity assumptions.

# %% [markdown]
# **Interpretation: Barrier Monitoring and Brownian Bridge Adjustment**
#
# - Analyse how the barrier-monitoring step classifies each simulated path according to whether the barrier level is breached during the contract horizon.
# - Discuss how discrete simulation intervals may otherwise fail to detect intermediate barrier breaches occurring between observed points, potentially biasing barrier-option valuation results.
# - Analyse how and explain that Brownian Bridge adjustment improves this classification by estimating hidden barrier crossings whether the stock price may have crossed the barrier (hidden barrier crossings) between discrete simulation timesteps, rather than relying only on the simulated prices directly observed at each timestep.
#
# - Explain how Brownian Bridge adjustment therefore reduces discretisation error and improves pricing reliability within the barrier-option simulation framework.
# - Discuss how this adjustment is especially important when Graph 1 shows paths moving close to the barrier line, because small unobserved movements between timesteps may determine whether the down-and-out put remains active or becomes deactivated.
# - Analyse how the use of Brownian Bridge adjustment in the simulation parameter table strengthens the pricing framework by reducing missed crossing events and improving the reliability of later valuation and activation results.

# %% [markdown]
# **Interpretation 2: Moneyness and Simulation Efficiency Analysis**
#
# - Analyse how Graph 2 links option moneyness to simulation efficiency by showing how pricing variance or error changes across different moneyness conditions.
# - Discuss why deep OTM barrier-option scenarios may produce lower simulation efficiency because many simulated paths generate zero or near-zero payoff outcomes, increasing estimator variance and reducing pricing stability.
#
# - Explain how this graph supports the use of Sobol Quasi-Monte Carlo methods because more uniform probability-space coverage helps reduce variance problems created by low-payoff or rare-payoff scenarios.
# - Analyse whether the observed variance pattern in Graph 2 confirms that Monte Carlo efficiency is weaker for OTM conditions and more stable when payoff participation is higher.

# %% [markdown]
# #### 5.3 Barrier Option Valuation Results

# %%
# Calculate terminal payoff for each simulated stock-price path
# Apply a down-and-out knock-out condition across all simulated paths
# Calculate payoff for all remaining active paths
# Discount simulated payoffs to present value using the risk-free rate
# Compute final barrier-option price as the average discounted payoff across all valid simulations

# Calculate active payoff path percentage --> measures the proportion of simunlated stock-price paths that actually contribute to the final option value
# Calculate average discounted payoff --> ths evaluates the acerage payoff contribution across surviving simulated paths

# Table 1 = Barrier Option Valuation Results Table --> columns = option type, strike price, barrier level, barrier-option value, average discounted payoff, active payoff path perfentage, inactive payoff path percentage

# Graph 1 = Sobol Quas-Monte Carlo Convergence Analysis --> x-axis = number of simulations, y-axis = estimated barrier-option price
    # Purpose = shows stabilization visually

# Graph 2 = Sobol Quas-Monte Carlo Convergence Analysis --> x-axis = number of simulations, y-axis = variance (error)
    # Purpose = numerically shows that simulation accuracy increases as simulation count increases
    # Put Graph 1 and 2 next to each other as one figure

# %% [markdown]
# **Interpretation: Barrier Option Valuation Behaviour**
#
# - Analyse how the barrier-option valuation results table demonstrates the relationship between conditional payoff eligibility and the final down-and-out put option value.
#
# - Explain how the barrier-option valuation is estimated as the discounted average payoff across all valid simulated stock-price paths according to:
#
# $V=e^{-rT}\frac{1}{N}\sum_{i=1}^{N}\text{Payoff}_i$
#
# where: V represents the barrier-option value, r is the risk-free rate, T is maturity, N is the number of simulations, $\text{Payoff}_i$ represents the payoff generated by each valid simulated stock-price path.
#
# - Discuss how the valuation results table demonstrates that only stock-price paths remaining above the barrier contribute to the final discounted payoff because paths breaching the barrier become deactivated under the knock-out condition.
# - Analyse whether the estimated barrier-option value appears relatively low compared with a standard vanilla put option due to the conditional payoff restrictions imposed by the barrier level.
#
# - Discuss how the active and inactive payoff path percentages reported in the valuation table influence the final option value because only active paths remain eligible to contribute positive discounted payoff outcomes.
# - Analyse whether a relatively high inactive-path percentage indicates that the selected barrier level creates substantial deactivation risk within the CSL.AX barrier-option framework.

# %% [markdown]
# **Interpretation: Monte Carlo Convergence and Pricing Stability**
#
# - Analyse how Graph 1 evaluates simulation convergence by examining whether pricing variance or standard error declines as the number of simulations increases.
# - Discuss how declining pricing variance within Graph 1 provides evidence that the Sobol Quasi-Monte Carlo framework improves convergence stability and reduces estimator uncertainty as additional simulated paths are incorporated into the pricing process.
# - Explain how lower pricing variance indicates that the estimated barrier-option value becomes less sensitive to random path variation and therefore numerically more reliable.
#
# - Analyse how Sobol low-discrepancy sequences improve convergence efficiency relative to standard pseudo-random Monte Carlo simulation because more uniform probability-space coverage reduces clustering behaviour across simulated stock-price paths.
# - Discuss how Graph 2 evaluates pricing consistency by analysing whether the estimated barrier-option value stabilises as simulation count increases.
#
# - Analyse whether the pricing trajectory in Graph 2 converges toward a relatively stable valuation level at higher simulation counts, supporting the reliability of the final estimated option value reported in the valuation table.
# - Discuss how convergence behaviour becomes particularly important within barrier-option pricing because relatively small differences in simulated stock-price paths near the barrier level may materially alter payoff eligibility and conditional valuation outcomes.
# - Analyse whether the convergence behaviour observed across Graph 1 and Graph 2 suggests that the selected simulation count is sufficient to produce stable and reliable barrier-option valuation estimates within the Sobol Quasi-Monte Carlo framework.

# %% [markdown]
# #### 5.4 Barrier Option Greeks and Sensitivity Analysis

# %% [markdown]
# (Introduce this subsection and talk about the methods you used to calculate the greeks e.g. finite differences etc.)

# %%
# Recalculate barrier-option value under varying stock-price conditions
    # Purpose = analyse Delta behaviour and stock-price sensitivity

# Recalculate barrier-option value under varying volatility assumptions
    # Purpose = analyse Vega behaviour and volatility sensitivity

# Recalculate barrier-option value under varying time-to-maturity assumptions
    # Purpose = analyse Theta behaviour and time-decay effects

# Recalculate barrier-option value under varying barrier-level assumptions
    # Purpose = analyse barrier proximity sensitivity and activation/deactivation risk

# Estimate Greeks numerically using finite-difference approximation --> Greeks = Delta, Vega, Theta

# Table 1 = Barrier Option Greeks Table --> columns = Delta, Vega, Theta, current barrier-option value


# Graph 1 = Stock Price vs Barrier Option Value --> x-axis = stock price, y-axis = barrier-option value
    # Purpose = analyse Delta behaviour and conditional payoff sensitivity

# Graph 2 = Volatility vs Barrier Option Value --> x-axis = volatility, y-axis = barrier-option value
    # Purpose = analyse Vega behaviour and volatility-driven barrier-crossing effects

# Graph 3 = Barrier Level vs Barrier Option Value --> x-axis = barrier level, y-axis = barrier-option value
    # Purpose = analyse barrier proximity sensitivity and deactivation risk

# Optional Graph 4 = Time to Maturity vs Barrier Option Value --> x-axis = time to maturity, y-axis = barrier-option value
    # Purpose = analyse Theta behaviour and time-decay dynamics

# %% [markdown]
# **Interpretation: Delta and Stock-Price Sensitivity Analysis**
#
# (this analysis section uses graph 1)
#
# - Analyse how the stock-price-versus-option-value graph demonstrates the sensitivity of the down-and-out put value to changes in the underlying CSL.AX stock price.
# - Discuss how Delta behaviour may become highly nonlinear near the barrier level because relatively small stock-price movements may significantly alter barrier-crossing probability and conditional payoff eligibility.
#
# - Explain how the barrier-option Delta differs from standard vanilla put-option Delta because the option value is influenced not only by terminal payoff positioning, but also by activation/deactivation risk throughout the contract life.
# - Analyse whether the option value declines sharply as the stock price approaches the barrier level due to increasing deactivation probability.

# %% [markdown]
# **Interpretation: Vega and Volatility Sensitivity Analysis**
#
# (this analysis section uses graph 2)
#
# - Analyse how the volatility-versus-option-value graph demonstrates the effect of changing volatility on barrier-option valuation.
#
# - Discuss how higher volatility simultaneously increases:
#     * downside payoff potential
#
#     * barrier-crossing probability.
# - Explain how this creates more complex Vega behaviour relative to standard vanilla options because volatility may either increase or reduce option value depending on the interaction between payoff potential and deactivation risk.
#
# - Analyse whether volatility increases overall barrier-option value or whether higher barrier-crossing probability partially offsets the additional downside exposure.

# %% [markdown]
# **Interpretation: Barrier Proximity Sensitivity Analysis**
#
# (this analysis section uses graph 3)
#
# - Analyse how the barrier-level-versus-option-value graph demonstrates the importance of barrier proximity within the down-and-out put structure.
# - Discuss how moving the barrier closer to the current stock price increases the probability of deactivation and therefore reduces conditional payoff participation.
#
# - Explain how barrier proximity becomes one of the most significant valuation drivers within exotic barrier-option pricing because payoff eligibility depends directly on barrier survival throughout the contract life.
# - Analyse whether option value declines nonlinearly as the barrier level approaches the current CSL.AX stock price.

# %% [markdown]
# **Interpretation: Theta and Time-Decay Behaviour Analysis**
#
# (this analysis section uses graph 4)
#
# - Analyse how the time-to-maturity-versus-option-value graph demonstrates the effect of time decay on the barrier-option valuation.
#
# - Discuss how longer maturities may simultaneously:
#     * increase downside payoff opportunity
#
#     * increase barrier-crossing probability.
# - Explain how this creates more complex Theta behaviour relative to standard vanilla options because additional time may either enhance payoff potential or increase deactivation risk depending on stock-price path evolution.
#
# - Analyse whether the barrier-option value decreases consistently as maturity shortens or whether conditional barrier risk alters traditional time-decay behaviour.

# %% [markdown]
# #### 5.5 Barrier Activation and Conditonal Payoff Analysis

# %%
# Identify all simulated stock-price paths greahing the barrier level --> determined which paths become deactivated under the down-and-under barrier
# Classify all simulated paths into "active" and "deactivated" paths

# Calculate barrier breach frequency --> measures how often the barrier level is crossed during the simulation
# Calculate barrier breach timing across timesteps --> purpose is to analyse when barrier-crossing events occur during the contract life
# Calculate conditional payoff participation rate
    # Purpose = determine the proportion of simulated paths remaining eligible for payoff generation

# Table 1 = Barrier Activation Summary Table --> columns = total simulated paths, active paths, deactivated paths, barrier breach frequency, conditional payoff participation rate

# Graph 1 = Barrier Activation / Deactivation Distribution --> x-axis = path classification (categories are "active" and "deactivated paths"), y-axis = percentage of simulated paths
    # Purpose = analyse the proportion of paths remaining eligible for payoff generation

# Graph 2 = Barrier Breach Frequency Distribution --> x-axis = timestep, y-axis = frequency of barrier breaches
    # Purpose = analyse when the barrier breaches most frequently occur during the simulation horizon

# %% [markdown]
# **Interpretation: Barrier Activation and Deactivation Behaviour**
#
# - Analyse how the Barrier Activation Summary Table demonstrates the proportion of simulated stock-price paths remaining active versus deactivated throughout the contract life within the down-and-out barrier structure.
#     * This directly illustrates how the barrier condition dynamically controls payoff eligibility throughout the option life rather than solely at maturity.
#
# - Discuss how simulated paths breaching the barrier level become permanently deactivated and therefore lose payoff eligibility regardless of subsequent stock-price recovery before expiration.
#     * This demonstrates that the barrier condition continuously influences payoff behaviour across the entire simulation horizon because a single barrier-crossing event permanently alters the derivative payoff outcome.
#
# - Analyse whether the proportion of deactivated paths appears economically significant relative to the total simulated path count.
#     * A high deactivation proportion indicates that barrier-crossing behaviour materially reduces expected payoff participation and therefore becomes a dominant driver of final option valuation.
#
# - Discuss how the conditional payoff participation rate reflects the proportion of simulated stock-price paths surviving the barrier condition and remaining eligible to contribute discounted payoff outcomes at maturity.
#     * This demonstrates how the barrier condition continuously filters the simulation population throughout the contract life, progressively reducing the number of payoff-eligible paths.
#
# - Analyse whether the active-path proportion appears sufficiently large to support meaningful payoff participation within the CSL.AX down-and-out put framework.
#     * This evaluates whether the selected barrier level creates a balanced derivative structure or whether excessive deactivation causes the barrier condition to dominate payoff behaviour too aggressively.

# %% [markdown]
# **Interpretation: Barrier Activation vs Deactivation Distribution**
#
# - Analyse how the Barrier Activation / Deactivation Distribution graph visualises the proportion of simulated stock-price paths surviving versus breaching the barrier condition during the contract horizon.
#     * This graph directly demonstrates how the barrier condition alters payoff behaviour by determining which simulated paths remain capable of generating terminal payoff outcomes.
#
# - Discuss whether the graph indicates that the selected barrier level materially restricts payoff participation due to elevated deactivation frequency.
#     * A large deactivated-path proportion suggests that the barrier condition substantially reduces the effective payoff exposure of the derivative relative to a standard vanilla put option.
#
# - Explain how the distribution graph reinforces the path-dependent nature of barrier-option valuation because payoff eligibility depends on continuous barrier survival throughout the option life rather than solely terminal stock-price positioning.
#     * This demonstrates how the barrier condition transforms payoff determination from a single maturity outcome into a continuously monitored path-dependent process.
#
# - Analyse whether the relative size of the active-path and deactivated-path categories suggests that barrier-crossing risk becomes a dominant determinant of final payoff behaviour.
#     * This highlights how survival probability becomes a critical component of derivative exposure within exotic barrier-option structures.

# %% [markdown]
# **Interpretation: Barrier Breach Frequency Distribution**
#
# - Analyse how the Barrier Breach Frequency Distribution graph demonstrates when barrier-crossing events occur most frequently throughout the simulation horizon.
#     * This reveals how the timing of barrier breaches influences payoff behaviour dynamically across the contract life rather than only at expiration.
#
# - Discuss whether barrier breaches appear concentrated during specific periods of the contract life or remain relatively distributed across the simulation timeframe.
#     * Concentrated breach periods may indicate intervals where the barrier condition becomes especially influential in determining payoff eligibility and derivative exposure.
#
# - Explain how earlier barrier breaches may reduce expected payoff participation more materially because paths become deactivated for the remaining duration of the option life.
#     * This demonstrates that the barrier condition affects not only whether payoff survives, but also how long simulated paths remain eligible to contribute to valuation outcomes.
#
# - Analyse whether the timing distribution of barrier breaches appears consistent with the volatility assumptions and simulated stock-price path behaviour established within the Sobol Quasi-Monte Carlo framework.
#     * This evaluates whether the observed payoff-survival behaviour appears economically consistent with the simulated market environment.
#
# - Discuss how periods with elevated breach frequency may indicate regions of heightened path-dependent risk exposure within the barrier-option structure.
#     * This reinforces how the barrier condition continuously reshapes payoff exposure throughout the option life by dynamically altering the proportion of surviving payoff-eligible paths.

# %% [markdown]
# ---

# %% [markdown]
# ### **Section 6: Derivative Pricing and Risk Analysis Comparison**

# %% [markdown]
# #### 6.1 Pricing Model Comparison

# %% [markdown]
# #### 6.2 Derivative Valuation Comparison

# %% [markdown]
# #### 6.3 Greeks and Risk Exposure Comparison

# %% [markdown]
# #### 6.4 Sensitivity and Moneyness Comparison

# %% [markdown]
# #### 6.5 Payoff and P&L Behaviour Comparison

# %% [markdown]
# ---

# %% [markdown]
# ### **Section 7 Export Derivative Pricing Outputs**
