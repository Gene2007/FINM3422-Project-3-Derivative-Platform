# %% [markdown]
# # FINM3422 - Project 3
#
# ### Risk & Derivatives Modelling Platform
# ---
# **Course**: FINM3411 - Financial Modelling
#
# **Group Members**:
# 1. Gene Wu
# 2. Patrick Liu
# 3. Alex Apelt
# 4. Rohith Porthugunta
#
# **Due**: Friday 29 May 2026, 4:00pm AEST
#
# **AI Usage**: Code structure and docstrings assisted by Claude (Anthropic)
#
# ----

# %% [markdown]
# ### **Section 1: Executive Summary & Methodology**

# %% [markdown]
# #### 1.1 Scenario
#
# - Talk about the investment banking trading desk environemnt and how it involves active portfolio managment, derivative exposure, and continuous monitoring of financialmarket risk across changing market conditions
#
# - Explain the role of trading and risk desks in prcing financial instruments, monitoring porfolio exposures, managing market risk, and supporting investment and hedging decisions within the environment
#
# - Discuss why financial institutions require sophisticated pricing and risk management systems capable of perfomring mark-to-market valuation, derivative pricing, portfolio aggregation, and real-time exposure anlaysis in response to a rapidly changing market
#
# - Analyse the different forms of portfolio risk faced by the investors/trading desks, including equity price risk, interest rate risk, volatility risk, and downside loss exposure resuilting from adverse market movements
#
# - Examine the importance of continuously monitoring porfolio risk in order to identify changing exposures, evaluate potantial loss, support regulatory and internal risk controls, and improve portfolio managment and trading decision-making processes
#
# - Explain the professional purpose of the platform as a quantitative finance and risk analytical system

# %% [markdown]
# #### 1.2 Project Objective
#
# - Talk about what we are trying to build in this project; for example: developing developing a prototype quantitative finance and risk analytics platform that is capavle for intergrating yield curve construction, derivative pricing, portfolio aggretation, and portfolio risk analysis
#
# - Explain the main objectives of the platform, including constructing yield curves, pricing options, aggregating portfolio positions, and analysing portfolio exposure under changing market conditions
#
# - Explain that the platform has been expanded to support multiple derivative structures including:
#     * European options
#     * American options
#     * Asian options
#     * barrier options
#
# - Discuss that the project integrates both analytical and simulation-based pricing frameworks to support broader derivative valuation and portfolio risk analysis
#
# - Explain that the platform aims to evaluate portfolio exposure and derivative sensitivity under a wider range of market conditions and derivative structures
#
# - Discuss that the project extends beyond traditional closed-form derivative pricing by incorporating advanced stochastic simulation techniques for quantitative-finance applications
#
# - Examine the role of the platform in supporting pricing analysis, portfolio exposure monitoring, scenario analysis, and downside risk evaluation
#
# - Discuss the final intended outcome that the platform should achieve

# %% [markdown]
# #### 1.3 Platform Overview
#
# - Explain the overall structure of the platform as a risk-analytical system that integrates market data proessing, yield curve construction, derivative pricing, portfolio valuation etc. into a unified workflow
#
# - Discuss how market data including historical equity prices and yield curve inputs flow through the platform, beginning with data collection, processing and then transformation into pricing inputs, portfolio valuations, and risk metrics
#
# - Describe the role of the market data layer in preparing historical equity prices, interest rate data, and volatility inputs used throughout the model
#
# - Explain the purpose of the yield curve layer in generating interest rate inputs required for discounting and derivative pricing applications
#
# - Discuss the derivative pricing layer and its role in pricing European, American, Asian, and barrier derivatives using both analytical and simulation-based pricing methodologies
#
# - Describe the role of the portfolio risk analytics layer in evaluating portfolio exposure throuhg VaR calculation, delta analysis, scenario testing, and stress-testing methodologies
#
# -
#
# Discuss the use of modular architecture and OOP principles in separating pricing logic, analytics, and data handling into reusable and scalable components (**this should be in methology section)

# %% [markdown]
# #### 1.4 Key Financial Questions Addressed
#
# - Discuss the key financial problems the platform is designed to address, including derivative valuation, portfolio exposure analysis, and portfolio risk management under changing market conditions
#
# - Examine how portfolio value and portfolio exposure respond to changes in equity prices, interest rates, and market volatility
#
# - Explain how the platform supports porfolio risk analysis, downside risk evaluation, and scenario-based risk assessment
#
# - Analyse how derivative positions influence portfolio behaviour and influence overall portfolio risk exposure
#
# - Discuss how the system supports downside risk analysis through scenario testing and portfolio revaluation under adverse market conditions

# %% [markdown]
# #### 1.5 Modelling Methodology
#
# Yield Curve Methodology:
#
# - Explain how the raw interest rate data is processed into maturity-rate pairs for yield curve construction
# - Discuss how interpolation is used to estimate interest rates between observed market maturities
#
# - Expalin how the interpolated yield curve creates a continuous term structure for pricing and valuation
# - Discuss how discount factors are generated from interpolated rates to support present value calculations
# - Explain how the yield curve provides risk-free rate inputs for option pricing and portfolio valuation
#
# Option Pricing Methodology:
#
# - Explain how European call and put options are priced using the B-S framework and MC simulation
# - Discuss how key pricing inputs are incorporated, including stock price, strike price, volatility, maturity, and risk-free rate (for B-S)
# - Discuss how the monte carlo simulation methods work
#
# - Explain how historial volatility is estimated from equity return data and used as a model input
# - Discuss how interpolated risk-free rates from the yield curve are matched to option maturities
# - Explain how option Greeks are calculated to measure sensitivity to stock price, volatility, and time-to-maturity changes
#
# Monte Carlo Simulation Methodology:
#
# - Explain that Monte Carlo simulation is used to numerically estimate derivative prices through stochastic simulation of risk-neutral asset-price paths
#
# - Discuss that asset prices are simulated using the Geometric Brownian Motion process under the risk-neutral measure (Display GBM equation)
#
# - Explain that simulated payoffs are averaged and discounted at the risk-free rate to estimate fair derivative values (display equation)
#
# - Discuss that Monte Carlo methods are especially useful for:
#     * path-dependent derivatives
#     * barrier options
#     * Asian options
#     * early-exercise derivatives
#
# - Explain that Monte Carlo pricing accuracy depends on:
#     * simulation count
#     * time-step discretisation
#     * variance reduction methodology
#
# Variance Reduction and Computational Methodlogy:
#
# - Explain that variance-reduction techniques are implemented to improve pricing efficiency and reduce simulation variance
#
# - Discuss antithetic variates and how negatively correlated simulation paths improve estimator stability
#
# - Explain that Sobol low-discrepancy sequences are used within a Quasi-Monte Carlo framework to improve convergence efficiency relative to pseudo-random sampling
#
# - Discuss how Brownian bridge/reflection-principle corrections improve barrier-crossing estimation between discrete simulation points
#
# - Explain that vectorised NumPy implementation is used to improve simulation runtime and computational scalability
#
# Portfolio Risk Methodology:
#
# - Explain how equity and derivative positions are aggregated into a single portfoio valuation framework
# - Discuss how portfolio value is calculated from individual position values and portfolio weights
#
# - Discuss how stress-testing scenarios are applied by shocking equity prices, interest rates, and volatility inputs
# - Explain how portfolio P&L and percentage changes are calcualted under each scenario to evaluate risk exposure
#
# Programming Methodology:
#
# - Explain how the codebase is structured into separate modules for data loading, yield curve construction, derivative pricing, portfolio valuation, risk anlaytics, and plotting
#
# - Discuss how modular design improves readability, reusability, and maintainability across the project
# - Explain how OOP/function-based design separates pricing logic, data processing, porftolio aggregation, and risk calculations

# %% [markdown]
# #### 1.6 Data and Inputs Used
#
# Equity Market Data:
#
# - Describe the source of historical equity price data used in the analysis (e.g. yfincance, bloomberg etc.)
#
# - Explain that historical stock prices are used to analyse market behaviour, calcualte returns, estimate volatilty, and support derivative pricing and portfolio valuation
#
# Yield Curve Data:
#
# - Describe the source of the interest rate data used to generate yield curve in the analysis (e.g. government bond yields, treasury yield datasets etc.)
# - Explain that the dataset contains interst rates across multiple maturities representing short-term and long-term market rates
#
# - Discuss the use of yield curve data as the primary source of risk-free rate inputs within the project
# - Expalin that the yield curve dataset provides the foundation for subsequent interest rate modelling and derivative value selections
# - Discuss the inclusion of different matuity obsevations to support consistent rate inputs across pricing and portfolio anlaysis components
#
# Derived Inputs:
#
# - Explain that historical volatility values are derived from historical equity return series
# - Discuss volatility as a key marekt input representing the magnitude of price fluctuations and market undertainty
# - Expalin that volatility estimates are incorporated into deriving pricing and portfolio risk analysis throughout the project
#
# - Explain that daily asset andp ortfolio returns are calculated from historical equity price data
# - Discuss returns as the primary inout for portoflio performance anlaysis and downside risk estimation
# - Explain that return series support statistical risk measures and portflio risk modelling sections later in the analysis
#
# - Explain that the rf rates are derived from the yield curve dataset across different maturities
# - Discuss the use of rf rates as a standard benchamark input for valuation and sicounting purposes within the project
# - Explain that maturity-specific rates are incorporated into derivative pricing and portfolio vlauation calculations

# %% [markdown]
# #### 1.7 Core Outputs and Risk Metrics
#
# Pricing Outputs:
#
# - Option prices generated using the B-S pricing framework for European call and put options
# - Monte Carlo derivative pricing outputs across multiple derivative structures
# - Simulation convergence outputs comparing pricing stability across simulation methodologies
# - Barrier-crossing and path-dependent pricing outputs for exotic derivatives
# - Interpolated yield curve outputs representing the term structure for interest rates across mulitple maturities
#
# - Discount factor outputs derived from interpolated yield curve rates for PV calculations
# - Option Greek measures e.g. Delta, Gamma, Vega, and Theta used to evaluate option sensitivity to changes in market variable
# - Sensitivity outputs showing how option values respond to movements in stock prices, volatility, interest rates, and time-to-maturity
#
# Portfolio Outputs:
#
# - Total portfolio value calculated from aggregated equity and derivative position values
# - Portfolio allocation and exposure summaries show the contribution of each position to overall portfolio value
#
# - Position breakdown outputs identify equity holdings, call option positions, and put option positions within the portfolio structure
# - Portfolio performacne outputs including P&L and percentage changes across stress-testing scenarios
#
# Risk Outputs:
#
# - Historical and parametric VaR estimares used to measure downside portfolio risk at selected confidence levels
# - Rolling VaR outputs illustrate how portfolio risk evolves over time under changing market conditions
# - Simulation variance and convergence diagnostics
# - Pricing-error comparison relative to analytical Black-Scholes benchmark values
#
# - Stress-testing scenario outputs evaluate portfolio resilience under simultaneous adverse market movements
# - Combined stress-testing scenairo outputs to evaluate portfolio resilience under simultaneous adverse market movements
# - Delta exposure and option sensitivity measures used to assess directional market exposure and derivative risk behaviour
#
# Visual Outputs:
#
# - Time-series charts used to illusrate historical equity price movments and portfolio performance over sample period
# - Yield curve plots and interpolation visualisations showing the term structure of interest rates and discount factor behaviour
# - Option pricing and Greek sensitivity plots demonstrating the relationship between option values and key pricing inputs
#
# - Monte Carlo convergence plots
# - Simulated stochastic asset-price path visualisations
# - Barrier-crossing path diagrams
# - Runtime and convergence comparison charts across pricing methodologies
# - Portfolio allocation charts, exposure composition plots, and valuation visualisations summarising portfolio structure
# - Distribution plots, VaR visualisations, rolling risk charts, and stress-testing graphs used to communicate portfolio downside risk and scenario outcomes
# - Summary tables presenting pricing outputs, portfollio valuation results, risk metrics, and stress-testing scenario comparisons

# %% [markdown]
# #### 1.8 Main Assumptions
#
# Financial Model Assumptions:
#
# - The Black-Scholes pricing framework assumed Eurpoean style otpions that can only be exercised at maturity
# - Financial markets are assumed to operate efficiencly, meaning asset prices fully and continuously relfect available market information
# - The Black-Scholes framework is built upon the core assumption of no-arbitrage within the financial market, meaning investors cannot generate risk-free profits through mispricing between the underlying asset and derivative contract
# - THe framework assumed risk-neutral valuation to determine the fair option price, meaning all market participants are assumed to be indifferent to risk and only demands the risk-free rate of return
#
# - Underlying asset prices are assumed to follow a geometric Brownian motion process with lognormally distributed prices and normally distributed returns
# - Volatility is assumed to remain constant throughout the option's life despite a changing market condition for calculation simplicity
# - Rf interest rates are assumed to remain stable during each pricing horizon for calculation simplicity
# - The model assumed frictionless markets with no transaction costs, taxes, liquidity constraints, or bid-ask spreads
# - Assumed continuous trading and the ability to continuously rebalance hedging portfolios throuhgouht the option's life
# - Dividend effect will be either ignored or assumed to remain constant depending on the pricing specification (specify)
#
# Monte Carlo Assumptions:
#
# - Monte Carlo simulations assume asset-price evolution follows a risk-neutral GBM process
# - Simulated stochastic shocks are assumed to follow normally distributed random variables
# - Monte Carlo estimates assume sufficient simulation paths and discretisation intervals to generate stable pricing estimates
#
# - Quasi-Monte Carlo methods assume low-discrepancy sampling improves convergence efficiency
# - Brownian bridge/reflection-principle corrections assume continuous barrier-crossing behaviour can be approximated between discrete monitoring intervals
#
#
# Yield Curve Assumptions:
#
# - Yield curve construction assumes that observed market rates represent the term structure of rf interest rates within the market
# - Yield curve interpolation asusmed that interest rates evolve smoothly between the observed market maturities
#
# - Yield curve interpolation assumes that the interpolated rates remain economically consistent across maturities and do not generate arbitrage opportunities within the term structure
# - Discount factor calcualtiion assumes consistent compounding conventions throughout the valuation framework
#
# Risk Model Assumptions:
#
# - Historical VaR assumes that historical market behaviour provides a meaningful approxmation of future downside portfolio risk exposure
# - Parametric VaR assumed portfolio retunrs are approximately normally distributed
# - Volatility and correlation structures are assumed to remains table during the estimation horizon
# - Historical return ovservations are asusmed to adequately capture portfolio risk behaviour and market dynamics
#
# - Stress-testing scenarios assume predefined market shocks that represent plausible and adverse market conditions
# - Risk analytics asume that portfolio sensitivity remanin stable throughout each stress-testing scenario
# - VaR calculation are assumed to have fixed confidence lvels and holding periods throughout the analysis
#
# Portfolio Assumptions:
#
# - Portfolio weights and position sizes are assumed to be static throughout the analysis period
# - Portfolio framework assumed simplified aggregation of equity and derivative positions into total position value
# - Transaction costs, taxed, liquidity constraints, slippage, and bid-ask spreads are ignored within the portfolio valuation calculations
#
# - Portfolio position are assumed to remain continuously available for valuation and re-pricing under stressed market conditions
# - Stress-testing scenarios assume market shocks are applied instantaneously across portfolio exposures

# %% [markdown]
# ----

# %% [markdown]
# ### **Section 2: Setup & Data Loading**

# %% [markdown]
# #### 2.1 Import Required Libraries

# %%
#import numpy, pandas, matplotlib, scipy, yfinance...

# %% [markdown]
# #### 2.2 Import Custom Proejct Modules

# %%
#import yieldcurve.py, derivatives.py, portfolio.py, risk.py

# %% [markdown]
# #### 2.3 Chart Styling

# %%
#code here

# %% [markdown]
# #### 2.4 Load Equity Market Data

# %%
# reading the CSV files, pulling API, displaying the first rows etc.

# %% [markdown]
# #### 2.5 Load Yield Curve Data

# %%
# load yield data, display dataset etc.

# %% [markdown]
# ---

# %% [markdown]
# ### **Section 3: Data Overview**

# %%
# checking datasets, ensure successful loading, identify missing values/formatting issues

# %% [markdown]
# ---

# %% [markdown]
# ### **Section 4: Market Data Preparation and Exploratory Analysis**

# %% [markdown]
# What to talk about in this section (before graph/introductory):
# - Introduce the chosen stocks/assets and explain why they were chosen
# - Selected equities = CBA.AX, BHP.AX, CSL.AX, WOW.AX
#
# - Mention sector exposure, liquidity, market relence, diversification considerations
#
# [Introduce here]

# %% [markdown]
# #### 4.1 Equity Price and Historical Returns Analysis

# %%
# Calculate historical stock prices
# Calculate daily returns (normal or log returns)

# Create equity market overview table (columns = stock, start price, end price, total return)

# Graph 1 = HIstorical Price Series Plot --> x-axis = time, y-axis = stock price
# Graph 2 = Normalised Price COmparison Plot --> rebase all stocks to 100
# Graph 3 = Daily Returns Time-Series Plot

# %% [markdown]
# **Interpretation: Historical Stock Returns Analysis**
#
# - Talk about its historical market behavious e.g. general price trend, periods of upwards/downwards movement, market volatility periods, overall performance
#
# - Discuss whether markets were volatile/stable and bullish/bearish during the dataset period
#
# [analyse here]

# %% [markdown]
# #### 4.2 Volatility and Risk Analysis

# %% [markdown]
# What to write here (opening/introduction):
# - Explain the importance of volatiliy as a measure of market uncertainty and financial risk
#
# - EXplain the theoretical relationship between volatility and protfolio risk exposure
# - Purpose of the subsection
#
# [write here]

# %%
# Calculate daily returns and historical volatility
# Calculate 30-day rolling volatility
# Calculate downside return metrics (minimum return, downside deviation, worst daily loss)

# Create volatility summary table (columns = stock, volatility, min return, max return)

# Graph 1 = 30-day ROlling VOlatility Plot
# Graph 2 = Return Disribution Histogram (with distribution curve)
# Graph 3 = Return Boxplot

# %% [markdown]
# **Interpretation: Volatility and Risk Analysis**
# - which stocks exhibited the highest volatility
# - identify period of elevated market uncertainty of instability
#
# - Discuss volatiliy clusturing and changing market risk over time
# - Interpret the return distribution (talk about: dispersion, asymmetry, extreme returns, downside tail behaviour)
# - discuss where some assets appeared riskier than others
#
# [analyse here]

# %% [markdown]
# #### 4.3 Correlation and Diversification Analysis

# %% [markdown]
# What to write here:
# - Importance of diversification in portfolio managment
# - COrrelation as a measure of how assets move relative with one another
#
# - Explain that lower correlation can reduce overall porfolio risk (try to include an equation)
# - Discuss the correlation analysis in portfolio construction, risk management, exposure diversification
# - Discuess how highly-correlaed assets may increase concentration risk
# - Explain that diversification benefits are strongest when assets exhibit low correlation which reduces portfolio risk
# - Discuss purpose of this subsection
#
# [write here]

# %%
# Table 1 = Correlation Matrix (with heatmap)

# %% [markdown]
# **Interpretation: Correlation and Diversification Analysis**
# - Which assets exhibited the highest positive correlation
#
# - WHich assets appeared more diversifies/weakly correlated
# - Discuess the diversification benefits across the selected equities
# - Identify any concentration risk caused by highly-correlated positions
# - INterpret if the portfolio apears well-diversified or concentrated
#
# [analyse here]

# %% [markdown]
# ---

# %% [markdown]
# ### **Section 5: Yield Curve Construction and Interest Rate Modelling**

# %% [markdown]
# What to write:
# - Discuss what the yield curve is and its importance
#
# - Explain the theoretical term structure concept e.g. relationship between interest rates and time to maturity
# - Explain role of yield curve in pricing/risk management
#
# [write here]

# %%
# Load yield curve dataset
# Display raw yield curve table

# %% [markdown]
# #### 5.1 Yield Curve Interpolation and Discount Factor Analysis

# %%
# Extract observed maturities from yield curve dataset
# Calculate raw interest rates for each maturity
# Calculate discount factor for each maturity
# Generate a dense maturity grid e.g. create maturioty points between the observed maturities
# Interpolate the yield/interest rates
# Use interpolated yield curve to interpolate discount factor curve

# Create interpolated yield curve with disount rate table (column 1 = maturity e.g. 0.5Y/1Y/2Y/5Y/10Y, column 2 = interpolated yield, column 3 = discount factor)

# Graph 1 = Raw vs Interpolated Yield Curve vs Discount Plot (line chart + scattered points)

# %% [markdown]
# **Interpretation: Yield Curve Interpolation and Discount Factor Analysis**
#
# <u>Interpolated Yield Curve Analysis:</u>
#
# - Compare raw observed market rates and interpolated curve
#
# - Write about how interpolation smooths the term structure between discrete maturity points
# - Analyse the shape of the yield curve e.g. does it appear upward/downward sloping, flat/curver etc.
# - Discuss what the shape of the curve may imply about market expectation and economic conditions
# - Analyse the differences between short-term and long-term rates
#
# <u>Interpolated Discount Rate Curve Analysis:</u>
#
# - Discuss how discount factors decline as maturity increase due to TV of money
# - Explain inverse relationship between interest rates and discount factors
#
# - Analyse how higher long-term interest rates reduce the present value of future cashflows
#
# [write here]

# %% [markdown]
# ---

# %% [markdown]
# ### **Section 6: Derivative Pricing and Monte Carlo Simultion Framework**

# %% [markdown]
# #### 6.1 Black-Scholes Pricing Framework and Model Implementation

# %% [markdown]
# What to write:
# - Role of derivative pricing in quantitative finance and risk management
# - Importance of option valuation
# - Introduce options derivative contracts (european, american, asian, barrier)
# - Introduce Black-Scholes pricing framework
# - Explain that Black-Scholes serves as the analytical benchmark framework for European option pricing
# - Discuss that Black-Scholes benchmark prices are used to evaluate Monte Carlo convergence accuracy and pricing stability
# - Explain limitations of Black-Scholes for:
#     * path-dependent derivatives
#     * barrier options
#     * early-exercise derivatives
#
# - Discuss main pricing assumptions (constant volatility, lognormal stock price behaviour, constant risk-free rate, no-arbitrage conditions)
# - Explain the key pricing inputs
# - Discuss how historical volatility estimates and interpolated rf rates are integrated into this framework
#
# [write here]

# %% [markdown]
# #### 6.2 Monte Carlo Pricing Framework and Simulation Architecture

# %% [markdown]
# What to write:
#
# - Talk about the Monte Carlo Pricing Logic
#
# - Explain that Monte Carlo pricing estimates derivative value through stochastic simulation of risk-neutral asset-price paths
#
# - Discuss the relationship between:
#     * risk-neutral valuation
#     * GBM path simulation
#     * discounted expected payoff estimation
#
# - Discuss the simulation's workflow
#   1. Generate random numbers
#   2. Simulate GBM asset-price paths
#   3. Apply derivative payoff logic
#   4. Detect barrier crossings if required
#   5. Calculate simulated payoffs
#   6. Average simulated payoffs
#   7. Discount expected payoff
#
# - Discuss the computational implementation of the Monte Carlo Simulation
# - Explain vectorised simulation implementation using NumPy arrays
# - Discuss how vectorisation improves runtime efficiency relative to iterative loop-based simulation
# - Explain modular separation between:
#     * derivative contracts
#     * pricing methodologies
#     * payoff calculations
#     * portfolio aggregation
#
# [write here]

# %% [markdown]
# #### 6.3 Selected Valuation Method for each Option Derivative

# %%
# Table 1 = Valuation method for each derivative --> columns = Derivative, Method

# %% [markdown]
#   - Explain why each methodology was chosen for each type of derivative

# %% [markdown]
# #### 6.4 European Option Pricing

# %% [markdown]
# ##### 6.4.1 European Option Pricing Inputs

# %% [markdown]
# Write notes like:
#
# - This subsection outlines the pricing inputs used to value the European call and put positions.
#
# - European options are used as the benchmark derivative class because they have closed-form Black-Scholes prices and can also be priced using Monte Carlo simulation.
#
# - The key pricing inputs are the underlying stock price, strike price, maturity, volatility, and maturity-matched risk-free rate.
#
# - Historical volatility is estimated from equity return data, while the risk-free rate is obtained from the interpolated yield curve.
#
# - Moneyness is included to identify whether each option is in-the-money, at-the-money, or out-of-the-money.
#
# [write here]

# %%
# For each European Options, extract: underlying stock, option type (call/put), position (long/short), current stock price, strike price, maturity, historical volatility, rf rate, quantity, moneyness (ITM, OTM), intrinsic value

# Table 1 = European Option Contract SPecifications --> columns = Underlying Asset, Option Type, Position, Strike, Maturity, Quanitity (this shows the contract assumptions before valuation)
# Table 2 = European Option Pricing Inputs --> columbs = Underlying, Option type, S0, K, Moneyness, Volatility, rf rate, Maturity, Intrinsic Value

# %% [markdown]
# **Interpretation: European Option Pricing Input Analysis**
#
# - Discuss whether the options are ITM, ATM, or OTM.
#
# - Determine which of the the call/put starts with intrinsic value.
#
# - Analyse how the strike compares to the current stock price.
#
# - Explain Whether the maturity is short or long relative to the option’s time value.
#
# - Analyse which input is likely to have the largest pricing effect: stock price, volatility, maturity, or interest rate.

# %% [markdown]
# ##### 6.4.2 Pricing Input and Valuation Results

# %%
# Calculate d1 and d2 in Black-Scholes Model
# Determine european call option price
# Determine european put option price

# Determine european call/put option prices using standard risk-neutral Monte Carlo 

# (note: how do i put the monte carlo simulation path illustrations)

# Table 1 = option pricing results table --> columns = option, type, d1, d2, IV, TV, option price)

# %% [markdown]
# **Interpretation: Option Pricing Results Analysis**
#
# <u>Overall Pricing Behaviour:</u>
# - Compare the option premiums of the different valuation methods
# - Analyse whether the European option premiums appear relatively high or low compared with the underlying stock prices and strike prices
# - Explain that option premiums reflect:
#     * expected future payoff potential
#     * uncertainty surrounding future stock-price movement
#     * remaining time until expiry
#
# - Discuss whether the observed premiums appear primarily driven by:
#     * intrinsic value
#     * speculative time value
# - Analyse whether the option valuations appear economically reasonable relative to:
#     * stock-price positioning
#     * strike-price positioning
#     * contract maturity
#
# <u>Call vs Put Valuation:</u>
# - Analyse whether the call-option premiums are relatively large or small compared with the strike price and underlying stock price
# - Explain that higher call-option value generally reflects stronger expected upside payoff opportunity
# - Discuss whether the call positions appear ITM, ATM, OTM based on their observed premiums
#
# - Analyse whether the put-option premiums are relatively large or small relative to the stock price and strike price
# - Explain that larger put-option premiums may reflect:
#     * downside market uncertainty
#     * protective hedging value
#     * stronger probability of adverse market movement
#
# - Compare whether call or put premiums are larger
# - Analyse whether valuation differences are primarily driven by:
#     * moneyness
#     * remaining maturity
#     * volatility level
#
# <u>Moneyness Analysis:</u>
# - Explain that ITM options contain intrinsic value because immediate exercise would generate positive payoff
# - Discuss why ITM options generally exhibit larger premiums
# - Analyse how deeper ITM positioning increases current option value
#
# - Explain that ATM options possess minimal intrinsic value but substantial time value
# - Discuss that ATM premiums primarily reflect future uncertainty and speculative payoff opportunity
#
# - Explain that OTM options contain little or no intrinsic value
# - Discuss that OTM premiums primarily reflect speculative future payoff potential
# - Analyse whether observed OTM premiums remain meaningful despite lack of exercise profitability
#
#
# [analyse here]

# %% [markdown]
# ##### 6.4.3 European Option Greeks and Sensitivity Analysis

# %%
# Calculate delta, vega, gamma, theta for each call/put option

# Table 1 = Greeks Summary Table --> columns = option, type, delta, vega, gamma, theta

# Graph 1 = Option Value vs Stock Price Plot (shows how price respond to stock price movement) --> plot put/call price against stock price
    # Overlay Monte Carlo estimated pricing points against the analytical Black-Scholes pricing curve to visually demonstrate that stochastic simulation reproduces the same non-linear pricing behaviour
# Graph 2 = Delta vs Stock Price Plot (shows how sentivie the option price is to stock price movements) --> plot put/call delta against stock price
    # Put Graph 1 and Graph 2 next to each other as one figure (to analyse stock price sensitivity)

# Graph 3 = Option Value vs Volatility Plot (shows how prices respond to volatility) --> plot put/call price against volatility
# Graph 4 = Vega vs Volatility Plot (shows how sensitive options are to volatility) --> plot put call vega against volatility
    # Put Graph 3 and Graph 4 next to each other as one figure (to analyse volatility sensitivity)

# Graph 5 = Option Value vs Time to Matuity (shows how option prices change as maturity changes) --> plot put/call price against time
# Graph 6 = Theta vs Time to Maturity (shows how time decay changes across maturities) --> plot put/call theta against time
    # Put Graph 5 and 6 next to each other as one figure (analyse Time to Maturity Sensitivity)

# %% [markdown]
# **Interpretation: Option Greeks and Sensitivity Analysis**
#
# <u>Sensitivity to Stock Price:</u>
#
# - Analyse the relationship between stock price movement and option valuation
# - Call option price increase as stock price rise
# - Put option price decrease as stock price rise
# - Provide reasoning on why (use FINM3405 content)
# - Is pricing behaviour of options linear/non-linear
#
# - What is the relationship between delta and stock price movement
# - Talk about how the put/call deltas move as the option become more ITM
# - Talk about how put delta becomes more negative as downside exposure increases
# - Discuss how the delta value reflects directional market exposure
# - Discuess how this overall analyses sensitivity to stock price movement
#
# <u>Sensitivity to Volatility:</u>
#
# - Analyse the relationship between volatility and option value
# - Provide explanation for the relationship e.g. option value increas volatility rises due to greater uncertainty (use content from FINM3405)
# - Explanation that higher volatility increases the probabilty of favourable option payoffs
# - Discuss how options become more valuable in volatile market conditions
#
# - Discuss relationship of vega and volatity (how it measures sensitivity of option vaue to volatility changes)
# - Analyse volatility exposure in derivative pricing
#
# <u>Sensitivty to Time to Maturity:</u>
#
# - Explain how this figure displays sensitivity to Time to Maturity
# - Relationship between maturity and option value
# - Provide theoretical explanation (FINM3405 content)
# - Discuss the TV component of the options and how it is connected to the observed relationship theoretically
#
# - Discuss how theta measures the rate that the option value decays over time
# - Analyse and explain how time decay accelerates as options approach expiry
# - Explain how short-dated options experience more rapid loss of TV
#
# [analyse here]

# %% [markdown]
# ##### 6.4.4 Option Payoff and Risk Behaviour

# %%
# Calculate payoff and P&L for each put/call option across a range of possible stock prices at maturity

# Table 1 = Payoff Summary Table --> columns = stock price at maturity, call payoff, put payoff, call P&L, put P&L

# Graph 1 = Put Payoff / P&L Diagram
# Graph 2 = Call Payoff / P&L Diagram
    # Put Graph 1 and Graph 2 next to each other as one figure

# Graph 3 = Combined Option Payoff and P&L Diagram

# %% [markdown]
# **Interpration: Option Payoff and P&L Diagram Analysis**
# - Analyse call option payoff and P&L trend
# - Call option payoff increases when stock prices rise above strike price
# - Limited downside risk for long call positions, with maximum loss restricted to the premium paid
# - Unlimited upside profit potential as stock price increases
# - Increasing profitability as the option becomes more ITM
# - Discuss the break-even stock price for the long call position and explain that profitability only occurs once the terminal stock price exceeds the strike price plus the premium paid
#
# - Put option values increase as stock prices decline below the strike price
# - Put options give the ability to provide downside protection during falling market conditions
# - Linmited downside loss to the premium paid for long put positions
# - Discuss the break-even stock price for the long put position and explain that profitability only occurs once the terminal stock price declines sufficiently below the strike price to offset the premium paid
# - Discuss how option positions exhibit asymmetric risk-return behaviour due to limited downside loss and non-linear upside payoff potential
# - Increasing profitability as market declines become larger
# - Explain that option payoff structures are inherently non-linear because profitability changes disproportionately as the underlying stock price moves further in-the-money
#
# - Analyse how the combined payoff diagram illustrates the contrasting behaviour between call and put option positions across changing terminal stock prices
# - Discuss how combined option payoff structures create asymmetric and non-linear portfolio exposure
# - Explain how the payoff profile demonstrates:
#     * limited downside loss
#     * leveraged upside exposure
#     * convex risk-return behaviour
# - Analyse how option payoff structures differ fundamentally from linear equity exposure
# - Discuss how derivative payoff asymmetry contributes to portfolio hedging and speculative positioning opportunities
#
# [analyse here]

# %% [markdown]
# #### 6.5 American Option Pricing

# %% [markdown]
# (note: price using binomial tree method)

# %%
# code here

# %% [markdown]
# [analyse here]

# %% [markdown]
# #### 6.6 Barrier Option Pricing

# %% [markdown]
# (note: price using Sobol Quasi-Monte Carlo with Brownian Bridge)

# %%
# code here

# %% [markdown]
# [analyse here]

# %% [markdown]
# ---

# %% [markdown]
# ### **Section 7: Portfolio Construction and Valuation**

# %% [markdown]
# What to write:
# - Purspoe of portfolio constructionin investment and risk management
# - IMportance of diversification across different asset classes and market exposures
#
# - Explain that the portfolio contains equity and derivative positions to create a balanced market exposure (add more reasoning here)
# - * Discuss how portfolio derivative exposure now includes:
#     * European
#     * American
#     * barrier derivatives
# - Explain that different derivative structures create different:
#     * convexity
#     * downside protection
#     * path dependence
#     * volatility sensitivity characteristics
# - Discuss how portfolio allocation influences: return potential, volatility, downside risk, hedging effectiveness
# - Discuss role of derivatives within the portfolio
#
# [write here]

# %% [markdown]
# #### 7.1 Portfolio Construction and Asset Allocation

# %%
# Determine asset/portfolio weights
# Determine the market value of each position (using stock prices, option prices, and quantities held)
# Calculate total portfolio value
# Determine the equity vs derivative exposure --> calculate allocation split between equities and derivatives

# Table 1 = Portfolio Composition Table --> columns = asset, asset type, quantity, price, position value, weight
# Table 2 = Exposure Summary Table --> columns = exposure type (equities/derivatives), portfolio share

# Graph 1 = Portfolio Allocation Chart (bar chart/pie chart)

# %% [markdown]
# **Interpretation: Allocation of Portfolio Weights**
# - Analyse the distribution of capital across equity and derivative positions
# - Discuss whether the portfolio appears concentrated or diversified across assets
# - Identify the largest portfolio allocations and their contribution to total assets
# - Analyse how the derivative positions influence overall portfolio structure and market exposure
#
# - Discuss how options may provide downside protection, leveraged exposure, or hedging characteristicss
# - Explain the balance between growth-oriented (asset) and defensive (options) portfolio exposures
# - Analyse how the allocation structure may affect portfolio volatility and sensitivity to market movements
# - Explain how the porftolio construction framework supports later portfolio risk analytics and stress-testing sections
#
# [analyse here]

# %% [markdown]
# #### 7.2 Portfolio Valuation and Derivative Exposure

# %%
# Calculate the market value of each stock position --> value = stock price * quantity held
# Calculate the market value of the option positions --> value = option price * contracts
# calculate total portfolio value --> total value = stock position value + option position value
# Calculate portfolio exposure contribution for equities/puts/calls --> contributiion = position value / total portfolio value

# Table 1 = Portfolio Valuation and Exposure Breakdown Table --> columns = asset, asset type, quantity, market price, position value/exposure value, portfolios hare

# Graph 1 = Portfolio Value Composition Pie Chart --> show contribution of equity/call/put to total portfolio value

# %% [markdown]
# **Interpretation: Portfolio Valuation and Exposure Analysis**
# - Analyse the contribution of equity and derivative positons to total portfolio value
# - Analyse the relative contribution of call and put option positions within the portfolio structure
#
# - Interpret the portfolio vlaue compositon pie chart by discussing the porportion of portfolio capital allocated to equities, calls, puts
# - Explain that portfolio derivative valuation incorporates multiple pricing methodologies depending on derivative structure and payoff characteristics
# - Discuss whether the portfolio allocation appears concentrated on reasonable diversified
# - Discuss how simulation-based pricing frameworks influence portfolio valuation stability under changing market conditions
# - Analyse the balance between growth-oriented exposure and downside protection within the overall structure
#
# [analyse here]

# %% [markdown]
# ---

# %% [markdown]
# ### **Section 8: Porfolio Risk Analysis and Stress Testing**

# %% [markdown]
# #### 8.1 Historical vs Parametric Value-at-Risk (VaR) Analysis

# %%
# Calculate daily portfolio returns
# Calculate Historical VaR
# Calculate Parametric VaR

# Include derivative positions within the portfolio return framework using the calculated option values and portfolio allocation structure

# Table 1 = VaR Summary Table --> columns = Confidence Level, Historicl VaR, Parametric VaR, Mean Return, Portfolio Volatility

# Graph 1 = Portfolio Return Distribution with VaR Line --> comparing historical vs parametric VaR)
# Graph 2 = Rolling VaR plot

# %% [markdown]
# **Interpretation: Value-at-Risk (VaR) Analysis**
#
# <u>VaR Model Comparison Analysis:</u>
#
# - ANalyse the estimated downside risk generated by the historical and paramteric VaR models
#
# - COmpare whether historical and parametric VaR produce similar or significantly different portfolio loss estimates
# - DIscuss which VaR methodology produces the largest risk estimate and what this may imply about portfolio return behaviour
# - Analyse how historical VaR captures realised histofical market movements and tail-risk behaviour using actula portfolio return observations
# - Discuss how parametric VaR relies on assumptions of normally distributed portfolio returns and volatility-based risk estimation
#
# <u>Portfolio Return Distribution Analysis:</u>
#
# - Interpret the portfolio return distribution with VaR line by discussing the location of the VaR threshold relative to the left tail of the return distribution
#
# - Analyse whether the portoflio return distribution appreas approximately normal or exhibis skewness and fat-tail behaviour
# - Discuss how non-normal return characteristics may affect the accuracy of parametric VaR estimates
#
# <u>Rolling VaR Analysis:</u>
#
# - Interpret the rolling VaR plot by analysing how portfolio risk evolves over time under changing market conditions
# - Discuss period of elevated rolling VaR and relate them to increases in market volatility or portfolio instability
#
# - Analyse whether the portoflio appears relatively stable or highly sensitive to adverse marekt movements based on VaR estimates
#
# <u>Strengths and Limitations of VaR Methodology:</u>
#
# - Discuss the strengths and limitations of both VaR methodologies in measuring portfolio downside risk
# - Does not describe losses beyond the threshold
# - Assumes stable correlations
#
# - May underestimate tail risk
#
# [analyse here]

# %% [markdown]
# #### 8.2 Equity Price Shock Scenarios

# %%
# Calculate Base Portfolio Value (our benchmark)
# Apply shocks to the stock price and revalue equity position
# Re-price the options using the relevant pricing methodology for each derivative structure (both call and put value; total option value = call + put)
# Calculate new portfolio value
# Calcualte option P&L for each scenario (call P&L = new call value - base call value, put P&L = new put value - base put value, )
# Calculate P&L for each scenario (TOtal option P&L = Call P&L + Put P&L)
# Calculate % change (% change = Scenario P&L / Base Portfolio Value)

# Table 1 = Summary Table --> colummns = scenario, shocked price, call value, put value, portfolio value, option P&L, total portfolio P&L, %change

# Graph 1 = Scenario P&L Bar Chart --> x-axis = equity shock scenarios, y-axis = portfolio P&L
# Graph 2 = Porfolio Value under Scenarios --> x-axis = equity shock scenarios, y-axis = total portfolio value
# Graph 3 = Equity vs Option Contribution Chart (stacked bar chart) --> show equity P&L contribution, option P&L contribution, total P&L

# %% [markdown]
# **Interpretation: Equity Price Shock Scenario Analysis**
#
# <u>Scenario P&L Analysis:</u>
#
# - Analyse how portfolio profit and loss changes under positive and negative equity shock scenarios
# - Discuss whether portfolio losses increase proportionally or disporportionally as equity shock severity increases
# - Identify which shock scenario gejnerate the largest porfolio gains and losses
#
# - Analyse whether the portfolio demonstrates significant sensitivity to adverse equity market movements
# - Discuss how derivative positions influence the magnitude of portfolio gains and losses under different market shocks
#
# <u>Portfolio Revaluation Analysis (Portfolio Value under Scenarios Plot):</u>
#
# - Analyse how total portfolio value changes across different shocked equity price scenarios
# - Discuss whether the portfolio valuation remains relativelys table or experiences substantial declines under negaative market stocks
# - Analyse the extent to which portfolio value recovers or increases under positive equity market scenarios
#
# - Discuss how portfolio revluaiton reflects the portfolio's overall directional market exposure
# - Analyse whether the portfolio appears highly exposed to equity market risk or partially protected through derivative positions
#
# <u>Equity vs Option Contribution Analysis:</u>
#
# - Analyse the relative contribution of equity and option positions to toal portfolio performance under each shock scenario
# - Discuss how equity positions dirve portfolio gains and losses under changing stock price conditions
#
# - Analyse how call option positions amplify upside participations during positive market shocks
# - Discuss how put option positions provide downside protection and partially offset equity losses during negative market shocks
# - Analyse whether derivative positions effectively reduce portfolio vulnurability under advers equity market conditions
#
# [analyse here]

# %% [markdown]
# #### 8.3  Interest Rate Shock Scenarios

# %%
# Calculate Base Portfolio Value (our benchmark)
# Define interest rate shocks and create shocked yield curves by shifting all rates by the same amount for each shock (this is called parallel yield shift)
# Re-calculate call/oput option values for each shocked yield curve (total option value = call + put)
# Re-calculate total portfolio value (Scenario Portfolio Value = Equity Value + Repriced Option Value)
# Calcualte option P&L for each scenario
# Calculate total porfolio P&L
# Calculate % change (%change = Scenario P&L / Base Portfolio Value)

# Table 1 = Summary Table --> column = rate shock, new interest rate, call value, put value, portfolio value, option P&L, total portfolio P&L, %change

# Graph 1 = Interest Rate Shock P&L Bar Chart --> x-axis = rate shock scenario, y-axis = portfolio P&L
# Graph 2 = Portfolio Value Under Rate Shocks --> x-axis = rate shock, y-axis = portfolio value
# Graph 3 = Option Value Sensitivitu to Rate Shocks --> x-axis = rate shock, y-axis = option value

# %% [markdown]
# **Interpretation: Interest Rate Shock Scenario Analysis**
#
# <u> Interest Rate Shock P&L Analysis:</U>
#
# - Analyse how portfolio profit and loss changes under positive and negative interest rate shock scenarios
# - Discuss whether riisng interest rates generate portfolio gains or losses and compare this with falling rate environments
#
# - Identify which interest rate shock scenario produce the largest portfolio valuation changes
# - Analyse whether the portfolio appears highly sensitive or relatively stable under changing interest rate conditions
#
# <u>Portfolio Revaluation under Interest Rate Shocks:</u>
#
# - Analyse how total portfolio value changes across different shocked interest rate scenarios
# - Discuss wheter the portfolio experiences substantial revaluation under large upward/downward yield curve shifts
#
# - Analyse whether portfolio valuation changes symmetrically or asymmetrically across positive and negative rate shocks
# - Discuss how interest rate sensitivity contribute to overall portfolio risk exposure
# - Analyse whether the portfolio structure appears vulnurable to canging monetary policy or market rate conditions
#
# <u>Option Sensitivity to Interest Rate Shocks:</u>
#
# - ANalyse how call and put options respond to changing interest rate environments
# - Discuss how higher interest rates affect call option alues relative to put option values under the B-S Model framework
#
# - Analyse whether option valuations exhibit strong or relatively limited sensitivity to interest rate movements compared with equity price shocks
# - Discuss whether these derivative positions amplify or partially offset portfolio exposure to changing interest rate conditions
#
# [analyse here]

# %% [markdown]
# #### 8.4 Volatility Shock Scenarios

# %%
# Calculate base portfolio value
# Apply shock to base volatility and determine volatility for each scenario
# Calculate new call/put price and total opton value
# Re-calculate total portfolio value
# Calculate call/put option P&L for each scenario
# Calculate total option P&L
# Calculate total portfolio P&L
# Calculate %change

# Table 1 =  Summary Table --> column = volatility shock, new volatility, call value, put value, option P&L, portfolio value, total P&L, %change

# Graph 1 = VOlatility Sensitivity Plot --> x-axis = new volatility (post-shock), y-axis = portfolio vlaue
# Graph 2 = Option Value (both put and call value lines) vs Post-Shock Volatility Plot
# Graph 3 = VOlatility Shock P&L Bar Chart --> x-axis = volatility shock, y-axis = total portfolio P&L

# %% [markdown]
# **Interpretation: Volatility Shock Scenario Analysis**
#
# <u>Volatility Shock P&L Analysis:</u>
#
# - Analyse how total portfolio profit and loss changes under positive and negative volatility shock scenarios
# - Discuss which volatility shock scenarios generate the largest portfolio gains or losses
#
# - Analyse whether the portfolio benefits from rising volatility conditions or performs better in stable market environments
# - Discuss how derivative positions contribute to portfolio P&L behaviour under changing volatility conditions
# - Analyse whether the portfolio appears highly exposed or relatively resilient to volatility risk
#
# <u>Volatility Sensitivity Analysis:</u>
#
# - Analyse how portfolio value changes as market volatility increases/decreases under different shock scenarios
# - Discuss whether the portfolio demonstrates significant sensitivity to volatility movements
# - Analyse portfolio valuation increases disporportionately under large upward volatility shocks
#
# - Discuss how derivative positions constirubte to the portfolio's volatility exposure relative to equity holdings
# - Analyse whether the portoflio exhibits convex or non-linear sensitivity to changing volatility conditions
# - Discuss how volatility shocks influance the uncertainty and risk profile of the portfolio
#
# <u>Option Value under Volatility Shocks:</u>
#
# - Analyse how call and put option values respond to changes in post-shock volatility levels
# - Discuss whether option valuations increase as volatility rises and explain the relationship between volatility and option pricing
# - Compare the sensitivity of call and put option positions to changing market volatility conditions
#
# - Analyse whether option values respond symmetrically or asymmetrically to volatility shocks
# - Discuss how volatility exposure contributes to derivative pricing risk within the portfolio structure
# - Analyse whether option positions amplify or partially offset portfolio sensitivity during volatile market environments
#
# [anlayse here]

# %% [markdown]
# #### 8.5 Combined Stress Testing

# %%
# Calculate base portfolio value
# Define combined stress scenarios and apply equity/rate/volatility shock (e.g. scenario = bull, mild stress, moderate stress, bear/extreme stress)
# Recalculate all pricing inputs --> for each scenario: calculate shock stock prices, shock interest rates, shock volatility; then rebuild pricing inputs, reprice options, recalcualte portfolio value)
# Reprice all portfolio positons (for each scenario: equity postion = use chocked stock prices, option positon = use shocked stock price/interest rate/volatility inside B-S model)
# Recalcualte new portfolio value (Scenario portfolio value = new equity value + new option value)
# Calculate scenario P&L (scenario porfolio value - base portfolio value)
# calculate %change

# Table 1 = Summary Table --> columns = scenario, equity shock, rate shock, volatility shock, portfolio value, equityu P&L, option P&L, TOtal P&L, %change

# Graph 1 = Stress Testing Heatmap --> x-axis = equity shocks, y-axis = volatility shocks, cell value = portfolio P&L
# Graph 2 = Scenario Comparison Bar Chart --> x-axis = scenario (bull, mild, moderate, bear), y-axis = portfolio value

# %% [markdown]
# **Interpretation: Combined Stress Testing Analysis**
#
# <u>Combined Stress Scenario Analysis</u>
#
# - Analyse how simultaneous equity, interest rate, and volatility shocks affect total portfolio valuation and profitability
# - Compare portfolio performance across mild, moderate, and severe combined stress scenarios
# - Identify which combined stress scnario generate the largest portfolio losses and discuss the primary drivers of the portfolio deterioration
# - Analyse whether the combined market shocks produce disproportionately larger losses relative to individual stress scenarios
#
# - Discuss how the ihteraction effects between equity, volatility, and interest rate shocks amplify overall portfolio risk exposure
# - Analyse where derivaative positions provide effective downside protection under extreme multi-factor stress conditons
# - Discuss whether the portfolio appears resilient or highly bulnerable when exposed to simultaneous adverse market movements
#
# <u>Stress Testing Heatmap Analysis</u>
#
# - Interpret the heatmap by analysing how portfolio P&L changes across combinations of equity and volatility shock scenarios
# - Identfiy regions of the heatmap associated with the largest portfolio losses and highest portoflio vulnerability
# - Analyse whether portfolio losses intensify under simultaneous negative equity shocks and elevated volatlity conditions
#
# - Discuss whether the portfolio demonstrates asymmetric sensitivity to different combinations of market stress factors
# - Analyse how the heatmap highlights non-linear portfolio behaviour under extreme stress environments
# - Discuss how combined market shocks may amplify downside portfolio risk beyong standard VaR estimates
#
# <u>Scenario Comparsion Analysis</u>
#
# - Compare portfolio performance across the different combined stress scenarios using the scenario comparison bar chart
# - Analyse which scenarios produce the greatest portfolio drawdowns and discuss the corresponding market conditions
# - Discuss whether the portfolio performs more favourable under bullish or stabilising market environments relative to stressed conditions
#
# - Analyse the relative severity of combined stress scenarios compared with isolated equity, volatiliy, or interest rate shocks
# - Discuss how portfolio diversification and derivative exposure influence overall stress-testing performance
# - ANalyse whether the portfolio appears adequately hedged or remains significantly exposed to extreme market downturns

# %% [markdown]
# ---

# %% [markdown]
# ### **Section 9: Key Insights**

# %% [markdown]
# ---

# %% [markdown]
# ### **Section 10: Limitations**
