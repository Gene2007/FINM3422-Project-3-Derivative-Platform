# %% [markdown]
# # FINM3422 - Project 3
#
# ### Risk & Derivatives Modelling Platform
# ---
# **Course**: FINM3411 - Financial Modelling
#
# **Group Members**:
# 1. Gene Wu
# 2. Patrick Liu
# 3. Alex Apelt
# 4. Rohith Porthugunta
#
# **Due**: Friday 29 May 2026, 4:00pm AEST
#
# **AI Usage**: Code structure and docstrings assisted by Claude (Anthropic)
#
# ----

# %% [markdown]
# ### 1. Executive Summary & Methodology

# %% [markdown]
# #### 1.1 Scenario
#
# - Talk about the investment banking trading desk environemnt and how it involves active portfolio managment, derivative exposure, and continuous monitoring of financialmarket risk across changing market conditions
#
# - Explain the role of trading and risk desks in prcing financial instruments, monitoring porfolio exposures, managing market risk, and supporting investment and hedging decisions within the environment
#
# - Discuss why financial institutions require sophisticated pricing and risk management systems capable of perfomring mark-to-market valuation, derivative pricing, portfolio aggregation, and real-time exposure anlaysis in response to a rapidly changing market
#
# - Analyse the different forms of portfolio risk faced by the investors/trading desks, including equity price risk, interest rate risk, volatility risk, and downside loss exposure resuilting from adverse market movements
#
# - Examine the importance of continuously monitoring porfolio risk in order to identify changing exposures, evaluate potantial loss, support regulatory and internal risk controls, and improve portfolio managment and trading decision-making processes
#
# - Explain the professional purpose of the platform as a quantitative finance and risk analytical system

# %% [markdown]
# #### 1.2 Project Objective
#
# - Talk about what we are trying to build in this project; for example: developing developing a prototype quantitative finance and risk analytics platform that is capavle for intergrating yield curve construction, derivative pricing, portfolio aggretation, and portfolio risk analysis
#
# - Explain the main objectives of the platform, including constructing yield curves, pricing European options, aggregating portfolio positions, and analysing portfolio exposure under changing market conditions
#
# - Examine the role of the platform in supporting pricing analysis, portfolio exposure monitoring, scenario analysis, and downside risk evaluation
#
# - Discuss the final intended outcome that the platform should achieve

# %% [markdown]
# #### 1.3 Platform Overview
#
# - Explain the overall structure of the platform as a risk-analytical system that integrates market data proessing, yield curve construction, derivative pricing, portfolio valuation etc. into a unified workflow
#
# - Discuss how market data including historical equity prices and yield curve inputs flow through the platform, beginning with data collection, processing and then transformation into pricing inputs, portfolio valuations, and risk metrics
#
# - Describe the role of the market data layer in preparing historical equity prices, interest rate data, and volatility inputs used throughout the model
#
# - Explain the purpose of the yield curve layer in generating interest rate inputs required for discounting and derivative pricing applications
#
# - Discuss the derivative pricing layer and its role in pricing European Call and Put options using market inputs
#
# - Describe the role of the portfolio risk analytics layer in evaluating portfolio exposure throuhg VaR calculation, delta analysis, scenario testing, and stress-testing methodologies
#
# Discuss the use of modular architecture and OOP principles in separating pricing logic, analytics, and data handling into reusable and scalable components (**this should be in methology section)

# %% [markdown]
# #### 1.4 Key Financial Questions Addressed
#
# Write about:
# - what financial problems the platform answers
# - how the porfolio reacts to market changes
# - how risk exposure is measures
# - HOw derivative positions affect risk
# - how the system helps analyse downside risk
# - what insight traders/risk managers gain

# %% [markdown]
# #### 1.5 Modelling Methodology
#
# Yield Curve Methodology:
# - how rates are processed
# - how interpolation is used
# - how discount factors are generated
#
# Option Pricing Methodology:
# - how options are priced
# - how volatility is eestimated
# - how risk-free rates are incorporated
#
# Portfolio Risk Methodology:
# - how positions are aggregated
# - how portfolio risk is measured
# - how stress testing/scenarios are applied
#
# Programming Methodology:
# - how the code base is structured
# - use of OOP and modular design
# - separation of pricing/risk/data logic

# %% [markdown]
# #### 1.6 Data and Inputs Used
#
# Equity Market Data:
# - source of price data
# - what it is used for
# - historical price analysis
#
# Yield Curve Data:
# - source of interest rate data
# - maturities/rates used
# - how rates are applied in valuation
#
# Derived Inputs:
# - volatility
# - returns
# - risk-free rates
# - scenario parameters

# %% [markdown]
# #### 1.7 Core Outputs and Risk Metrics
#
# Pricing Outputs:
# - option prices
# - yield curve outputs
# - greeks
#
# Portfolio Outputs:
# - porfolio value
# - exposure summary
# - position breakdown
#
# Risk Outputs:
# - VaR
# - stress test results
# - scenario analysis
# - delta exposure
#
# Visual Outputs:
# - charts
# - plots
# - tables
# - distribution

# %% [markdown]
# #### 1.8 Main Assumptions
#
# Financial Model Assumptions:
# - assumptions within Black-Scholess
# - assumptions about markets and volatility
#
# Yield Curve Assumptions:
# - interpolation assumptions
# - rate movement assumptions
#
# Risk Model Assumptions:
# - assumptions used in VaR
# - assumptions about historical data
#
# Portfolio Assumptions:
# - simplifications used
# - ignored market frictions
# - static portfolio assumption
#
# ----

# %% [markdown]
# ### 2. Setup & Data Loading

# %% [markdown]
# #### 2.1 Import Required Libraries

# %%
#import numpy, pandas, matplotlib, scipy, yfinance...

# %% [markdown]
# #### 2.2 Import Custom Proejct Modules

# %%
#import yieldcurve.py, derivatives.py, portfolio.py, risk.py

# %% [markdown]
# #### 2.3 Chart Styling

# %%
#code here

# %% [markdown]
# #### 2.4 Load Equity Market Data

# %%
# reading the CSV files, pulling API, displaying the first rows etc.

# %% [markdown]
# #### 2.5 Load Yield Curve Data

# %%
# load yield data, display dataset etc.

# %% [markdown]
# ### 3. Data Overview

# %%
# checking datasets, ensure successful loading, identify missing values/formatting issues

# %% [markdown]
# ---

# %% [markdown]
# ### 4. Market Data Preparation and Exploratory Analysis

# %% [markdown]
# #### 4.1 Equity Market Overview
# What to do:
# - Introduce the selected stocks/assets
# - Explain why they were chosen
# - Load and display historical price data
# - Show basic market behaviour/trends
#
# Include:
# - Summary statistics
# - Stock price charts
# - Dataset preview

# %%
#code here

# %% [markdown]
# [analyse here]

# %% [markdown]
# #### 4.2 Historical Returns Analysis
#
# What to do:
# - Calculate daily log returns
# - Explain why returns are used instead of prices
# - Analyse return behaviour
#
# Include:
# - Returns table
# - Return time-series plot
# - basic return statistics

# %%
#code here

# %% [markdown]
# [analyse here]

# %% [markdown]
# #### 4.3 Volatility Estimation
#
# What to do:
# - Estimate historical volatility from returns
# - Annualise volatility
# - Explain why volatility is important in option pricing
#
# Include:
# - rolling volatility plot
# - volatility calculations
# - volatility interpretations

# %%
#code here

# %% [markdown]
# [analyse here]

# %% [markdown]
# #### 4.4 Exploratory Price Analysis
#
# What to do:
# - Analyse market trends and price movements
# - COmpare behaviour across assets
# - Identify period of high/low volatility
#
# Include:
# - stock price charts
# - moving averages
# - trend discussion

# %%
#code here

# %% [markdown]
# [analyse here}]

# %% [markdown]
# #### 4.5 Return Distribution Analysis
#
# What to do:
# - Analyse the statistical behaviour of returns
# - Identify skewness, tails, and extreme observations
# - Discuss implications for risk modelling
#
# Include:
# - histogram of returns
# - boxplots
# - descriptive statistics

# %%
#code here

# %% [markdown]
# [analyse here]

# %% [markdown]
# #### 4.6 Correlation Analysis
#
# What to do:
# - Analyse relationships between assets
# - Examine diversification effects
# - Understand portfolio interaction
#
# Include:
# - Correlation matrix
# - Correlation heatmap
# - Discussion of asset relationships

# %%
#code here

# %% [markdown]
# [analyse here]

# %% [markdown]
# #### 4.7 Market Data Insights
#
# What to do:
# - Summarise and interpret key observations from the data
# - Discuss volatility/risk characteristics
# - Explain implications for pricing and portfolio risk
# - Transition to section 5: yield curve modelling and pricing sections
